# %%
import weaviate
from weaviate import Client
import csv
import json
import pandas as pd
import ast
import os
from langchain.vectorstores.weaviate import Weaviate
from langchain.chains.question_answering import load_qa_chain
from langchain.llms import AzureOpenAI
from langchain.prompts import PromptTemplate
from dotenv import load_dotenv
from langchain.chains import ChatVectorDBChain,ConversationalRetrievalChain,RetrievalQAWithSourcesChain,RetrievalQA
from langchain.document_loaders import JSONLoader
from pathlib import Path
from pprint import pprint

# %%
import os
import requests
import json
import openai
load_dotenv()
openai.api_key = os.getenv("OPENAI_API_KEY")
openai.api_base = os.getenv("OPENAI_ENDPOINT") # your endpoint should look like the following https://YOUR_RESOURCE_NAME.openai.azure.com/
openai.api_type = 'azure'
openai.api_version = '2023-05-15' # this may change in the future

deployment_name=os.getenv("OPENAI_DEPLOYMENT_NAME") #This will correspond to the custom name you chose for your deployment when you deployed a model. 

# Send a completion call to generate an answer
print('Sending a test completion job')
start_phrase = 'Write a tagline for an ice cream shop. '
response = openai.Completion.create(engine=deployment_name, prompt=start_phrase, max_tokens=10)
text = response['choices'][0]['text'].replace('\n', '').replace(' .', '.').strip()
print(start_phrase+text)
# Out:
# Sending a test completion job
# Write a tagline for an ice cream shop. "Scoops of happiness in every cone!"

# %%
client = weaviate.Client(
    url = "http://localhost:8080",  # Replace with your endpoint
    additional_headers = {
        "X-Azure-Api-Key": os.getenv("OPENAI_API_KEY")
    }
    
)
# Check if your instance is live and ready
# This should return `True`
client.is_ready()
# Out:
# True

# %%
client.query.aggregate("DataClass").with_meta_count().do()
# Out:
# {'data': {'Aggregate': {'DataClass': [{'meta': {'count': 39561}}]}}}

# %% [markdown]
# # Data Import

# %%
client.schema.delete_class("DataClass")

# %%
# This creates a class Question, specifying which vectorizer to use, sets the moduleConfig for the vectorizer and specifies the generative module to be used.
class_obj = {
    "class": "DataClass",
    "vectorizer": None,  # If set to "none" you must always provide vectors yourself. Could be any other "text2vec-*" also.00ff6900-e64f-5d94-90db-c8cfa3fc851b
    "moduleConfig": {
        "text2vec-openai": {},
        "generative-openai": {
            "model": "gpt-3.5-turbo",
            "resourceName": "nwj-openai",
            "deploymentId": "gf-model-deploy-002",
            "temperatureProperty": 0,
        },
    }
}

client.schema.create_class(class_obj)

# %%
df = pd.read_csv("final-dup.csv")
df.head()
# Out:
#                                              comment core_identity_groups
# 0  Yes indeed. She sort of reminds me of the elde...             ['race']  \
# 1  The trans women reading this tweet right now i...           ['gender']
# 2  Question: These 4 broads who criticize America...           ['origin']
# 3  It is about time for all illegals to go back t...           ['origin']
# 4  For starters bend over the one in pink and kic...           ['gender']
#
#                                  sub_identity_groups
# 0  ['asian', 'black', 'latinx', 'middle eastern',...  \
# 1                                ['transgender men']
# 2                                      ['immigrant']
# 3                                   ['undocumented']
# 4                                          ['women']
#
#                                            embedding
# 0  [-0.015919025987386703, -0.028737619519233704,...
# 1  [-0.017841871827840805, -0.013057178817689419,...
# 2  [-0.004760753363370895, -0.026184145361185074,...
# 3  [0.0033386661671102047, -0.011945863254368305,...
# 4  [-0.008337941952049732, -0.012026377953588963,...

# %%
# Check the datatype
print(type(df['comment'].iloc[0]))
print(type(df['core_identity_groups'].iloc[0]))
print(type(df['sub_identity_groups'].iloc[0]))
print(type(df['embedding'].iloc[0]))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>

# %%
df['core_identity_groups'] = df['core_identity_groups'].apply(ast.literal_eval)
df['sub_identity_groups'] = df['sub_identity_groups'].apply(ast.literal_eval)
df['embedding'] = df['embedding'].apply(ast.literal_eval)

# %%
# ===== import data =====
# Load data
data = df.to_dict(orient='records')

# %%
data[0]
# Out:
# {'comment': 'Yes indeed. She sort of reminds me of the elder lady that played the part in the movie "Titanic" who was telling her story!!! And I wouldn\'t have wanted to cover who I really am!! I would be proud!!!! WE should be proud of our race no matter what it is!!',
#  'core_identity_groups': ['race'],
#  'sub_identity_groups': ['asian',
#   'black',
#   'latinx',
#   'middle eastern',
#   'native american',
#   'pacific islander',
#   'white'],
#  'embedding': [-0.015919025987386703,
#   -0.028737619519233704,
#   0.01290326938033104,
#   -0.035980645567178726,
#   -0.009131944738328457,
#   0.003080891678109765,
#   0.00793997198343277,
#   0.0042598373256623745,
#   0.00532479677349329,
#   -0.020999565720558167,
#   -0.011046918109059334,
#   0.018381133675575256,
#   0.009535782970488071,
#   -0.024699240922927856,
#   -0.018394161015748978,
#   0.01607535034418106,
#   0.0311345923691988,
#   -0.0035596347879618406,
#   0.00645489152520895,
#   -0.03381815925240517,
#   -0.010389053262770176,
#   0.014811728149652481,
#   0.012382187880575657,
#   -0.0025337564293295145,
#   -0.0263666994869709,
#   -0.010232728905975819,
#   0.03392237424850464,
#   -0.03220280632376671,
#   0.018198754638433456,
#   -0.036058805882930756,
#   -0.000440883421106264,
#   0.002756844274699688,
#   -0.0036605943460017443,
#   -0.015945078805088997,
#   -0.009894026443362236,
#   -0.010219701565802097,
#   -0.015945078805088997,
#   -0.027018051594495773,
#   -0.008304729126393795,
#   -0.0037420131266117096,
#   -0.03293232247233391,
#   -0.006510256323963404,
#   0.0009778410894796252,
#   -0.013092161156237125,
#   -0.020465457811951637,
#   0.013730484992265701,
#   -0.020960485562682152,
#   -0.010037323459982872,
#   -0.02356589026749134,
#   0.020452430471777916,
#   0.03611091524362564,
#   0.008962593972682953,
#   0.007373296655714512,
#   -0.023044809699058533,
#   -0.01662248559296131,
#   0.013639296405017376,
#   0.00039997039129957557,
#   0.002276472747325897,
#   0.008408945053815842,
#   0.010167594067752361,
#   0.007431918289512396,
#   0.01340480986982584,
#   -0.004937242716550827,
#   -0.006513513159006834,
#   -0.014108269475400448,
#   -0.02826864644885063,
#   -0.012238890863955021,
#   0.011177187785506248,
#   0.007223485969007015,
#   0.005292229354381561,
#   0.022341350093483925,
#   -0.01028483733534813,
#   -0.006396269891411066,
#   0.013059593737125397,
#   0.01113810669630766,
#   -0.008044188842177391,
#   -0.00532805360853672,
#   -0.004373823758214712,
#   -0.01543702557682991,
#   -0.006682864390313625,
#   0.010949214920401573,
#   -0.018368106335401535,
#   0.0006130844121798873,
#   0.019527511671185493,
#   0.020061619579792023,
#   0.012987945228815079,
#   -0.007080188486725092,
#   -0.011274890974164009,
#   0.010916647501289845,
#   -0.03874237462878227,
#   -0.009431567043066025,
#   -0.027226483449339867,
#   -0.009763755835592747,
#   -0.0043412563391029835,
#   0.008689026348292828,
#   -0.01395194511860609,
#   -0.009548810310661793,
#   -0.021624863147735596,
#   -0.0267314575612545,
#   -0.014082214795053005,
#   0.012193296104669571,
#   0.003605229314416647,
#   0.012805566191673279,
#   0.2171865701675415,
#   -0.0075556752271950245,
#   -0.027487024664878845,
#   0.023878538981080055,
#   -0.011515891179442406,
#   -0.004110026638954878,
#   0.02391761913895607,
#   0.014225511811673641,
#   0.0003767660236917436,
#   -0.0031997631303966045,
#   -0.023513780906796455,
#   -0.010421620681881905,
#   -0.01335270144045353,
#   0.0030971753876656294,
#   0.01866772770881653,
#   -0.026431836187839508,
#   -0.017013296484947205,
#   -0.025702321901917458,
#   0.006311594042927027,
#   -0.03501664474606514,
#   0.007861809805035591,
#   -0.02842497080564499,
#   0.0007067161495797336,
#   -0.021155890077352524,
#   0.018537458032369614,
#   0.01950145699083805,
#   0.029805835336446762,
#   0.015085295774042606,
#   0.008506648242473602,
#   -0.0033186348155140877,
#   -0.008630404248833656,
#   -0.0380910225212574,
#   0.008448026143014431,
#   -0.014368809759616852,
#   -0.015840863808989525,
#   -0.0038462292868644,
#   0.010180620476603508,
#   0.001283976249396801,
#   0.006754512898623943,
#   -0.013652322813868523,
#   -0.004552945494651794,
#   0.010421620681881905,
#   -0.013085647486150265,
#   -0.018915241584181786,
#   0.014955026097595692,
#   0.03874237462878227,
#   ...]}

# %%
# # Read the CSV file and convert each row to a dictionary
# with open("final-dup.csv", mode='r') as file:
#     reader = csv.DictReader(file)
#     rows_list = list(reader)

# # Convert the list of dictionaries to a string representation
# data = json.dumps(rows_list, indent=4)

# # Print the string representation of the list of dictionaries
# print(data)

# %%
# Prepare a batch process
# Configure batch
client.batch.configure(batch_size=20,
                       dynamic=True,
                       timeout_retries=3)

with client.batch as batch:
    # Batch import all Questions
    for i, d in enumerate(data):
        print(f"importing data: {i+1}")  # To see imports

        properties = {
            "comment": d["comment"],
            "core_identity": d["core_identity_groups"],
            "sub_identity": d["sub_identity_groups"],
        }

        batch.add_data_object(
            data_object=properties,
            class_name="DataClass",
            vector=d['embedding']
        )
# Out:
# importing data: 1
# importing data: 2
# importing data: 3
# importing data: 4
# importing data: 5
# importing data: 6
# importing data: 7
# importing data: 8
# importing data: 9
# importing data: 10
# importing data: 11
# importing data: 12
# importing data: 13
# importing data: 14
# importing data: 15
# importing data: 16
# importing data: 17
# importing data: 18
# importing data: 19
# importing data: 20
# importing data: 21
# importing data: 22
# importing data: 23
# importing data: 24
# importing data: 25
# importing data: 26
# importing data: 27
# importing data: 28
# importing data: 29
# importing data: 30
# importing data: 31
# importing data: 32
# importing data: 33
# importing data: 34
# importing data: 35
# importing data: 36
# importing data: 37
# importing data: 38
# importing data: 39
# importing data: 40
# importing data: 41
# importing data: 42
# importing data: 43
# importing data: 44
# importing data: 45
# importing data: 1004
# importing data: 1005
# importing data: 1006
# importing data: 1007
# importing data: 1008
# importing data: 1009
# importing data: 1010
# importing data: 1011
# importing data: 1012
# importing data: 1013
# importing data: 1014
# importing data: 1015
# importing data: 1016
# importing data: 1017
# importing data: 1018
# importing data: 1019
# importing data: 1020
# importing data: 1021
# importing data: 1022
# importing data: 1023
# importing data: 1024
# importing data: 1025
# importing data: 1026
# importing data: 1027
# importing data: 1028
# importing data: 1029
# importing data: 1030
# importing data: 1031
# importing data: 1032
# importing data: 1033
# importing data: 1034
# importing data: 1035
# importing data: 1036
# importing data: 1037
# importing data: 1038
# importing data: 1039
# importing data: 1040
# importing data: 1041
# importing data: 1042
# importing data: 1043
# importing data: 1044
# importing data: 1045
# importing data: 1046
# importing data: 1047
# importing data: 1048
# importing data: 1049
# importing data: 1050
# importing data: 1051
# importing data: 1052
# importing data: 1053
# importing data: 1054
# importing data: 1055
# importing data: 1056
# importing data: 1057
# importing data: 1058
# importing data: 1059
# importing data: 1060
# importing data: 1061
# importing data: 1062
# importing data: 1063
# importing data: 1064
# importing data: 1065
# importing data: 1066
# importing data: 1067
# importing data: 1068
# importing data: 1069
# importing data: 1070
# importing data: 1071
# importing data: 1072
# importing data: 1073
# importing data: 1074
# importing data: 1075
# importing data: 1076
# importing data: 1077
# importing data: 1078
# importing data: 1079
# importing data: 1080
# importing data: 1081
# importing data: 1082
# importing data: 1083
# importing data: 1084
# importing data: 1085
# importing data: 1086
# importing data: 1087
# importing data: 1088
# importing data: 1089
# importing data: 1090
# importing data: 1091
# importing data: 1092
# importing data: 1093
# importing data: 1094
# importing data: 1095
# importing data: 1096
# importing data: 1097
# importing data: 1098
# importing data: 1099
# importing data: 1100
# importing data: 1101
# importing data: 1102
# importing data: 1103
# importing data: 1104
# importing data: 1105
# importing data: 1106
# importing data: 1107
# importing data: 1108
# importing data: 1109
# importing data: 1110
# importing data: 1111
# importing data: 1112
# importing data: 1113
# importing data: 1114
# importing data: 1115
# importing data: 1116
# importing data: 1117
# importing data: 1118
# importing data: 1119
# importing data: 1120
# importing data: 1121
# importing data: 1122
# importing data: 1123
# importing data: 1124
# importing data: 1125
# importing data: 1126
# importing data: 1127
# importing data: 1128
# importing data: 1129
# importing data: 1130
# importing data: 1131
# importing data: 1132
# importing data: 1133
# importing data: 1134
# importing data: 1135
# importing data: 1136
# importing data: 1137
# importing data: 1138
# importing data: 1139
# importing data: 1140
# importing data: 1141
# importing data: 1142
# importing data: 1143
# importing data: 1144
# importing data: 1145
# importing data: 1146
# importing data: 1147
# importing data: 1148
# importing data: 1149
# importing data: 1150
# importing data: 1151
# importing data: 1152
# importing data: 1153
# importing data: 1154
# importing data: 1155
# importing data: 1156
# importing data: 1157
# importing data: 1158
# importing data: 1159
# importing data: 1160
# importing data: 1161
# importing data: 1162
# importing data: 1163
# importing data: 1164
# importing data: 1165
# importing data: 1166
# importing data: 1167
# importing data: 1168
# importing data: 1169
# importing data: 1170
# importing data: 1171
# importing data: 1172
# importing data: 1173
# importing data: 1174
# importing data: 1175
# importing data: 1176
# importing data: 1177
# importing data: 1178
# importing data: 1179
# importing data: 1180
# importing data: 1181
# importing data: 1182
# importing data: 1183
# importing data: 1184
# importing data: 1185
# importing data: 1186
# importing data: 1187
# importing data: 1188
# importing data: 1189
# importing data: 1190
# importing data: 1191
# importing data: 1192
# importing data: 1193
# importing data: 1194
# importing data: 1195
# importing data: 1196
# importing data: 1197
# importing data: 1198
# importing data: 1199
# importing data: 1200
# importing data: 1201
# importing data: 1202
# importing data: 1203
# importing data: 1204
# importing data: 1205
# importing data: 1206
# importing data: 1207
# importing data: 1208
# importing data: 1209
# importing data: 1210
# importing data: 1211
# importing data: 1212
# importing data: 1213
# importing data: 1214
# importing data: 1215
# importing data: 1216
# importing data: 1217
# importing data: 1218
# importing data: 1219
# importing data: 1220
# importing data: 1221
# importing data: 1222
# importing data: 1223
# importing data: 1224
# importing data: 1225
# importing data: 1226
# importing data: 1227
# importing data: 1228
# importing data: 1229
# importing data: 1230
# importing data: 1231
# importing data: 1232
# importing data: 1233
# importing data: 1234
# importing data: 1235
# importing data: 1236
# importing data: 1237
# importing data: 1238
# importing data: 1239
# importing data: 1240
# importing data: 1241
# importing data: 1242
# importing data: 1243
# importing data: 1244
# importing data: 1245
# importing data: 1246
# importing data: 1247
# importing data: 1248
# importing data: 1249
# importing data: 1250
# importing data: 1251
# importing data: 1252
# importing data: 1253
# importing data: 1254
# importing data: 1255
# importing data: 1256
# importing data: 1257
# importing data: 1258
# importing data: 1259
# importing data: 1260
# importing data: 1261
# importing data: 1262
# importing data: 1263
# importing data: 1264
# importing data: 1265
# importing data: 1266
# importing data: 1267
# importing data: 1268
# importing data: 1269
# importing data: 1270
# importing data: 1271
# importing data: 1272
# importing data: 1273
# importing data: 1274
# importing data: 1275
# importing data: 1276
# importing data: 1277
# importing data: 1278
# importing data: 1279
# importing data: 1280
# importing data: 1281
# importing data: 1282
# importing data: 1283
# importing data: 1284
# importing data: 1285
# importing data: 1286
# importing data: 1287
# importing data: 1288
# importing data: 1289
# importing data: 1290
# importing data: 1291
# importing data: 1292
# importing data: 1293
# importing data: 1294
# importing data: 1295
# importing data: 1296
# importing data: 1297
# importing data: 1298
# importing data: 1299
# importing data: 1300
# importing data: 1301
# importing data: 1302
# importing data: 1303
# importing data: 1304
# importing data: 1305
# importing data: 1306
# importing data: 1307
# importing data: 1308
# importing data: 1309
# importing data: 1310
# importing data: 1311
# importing data: 1312
# importing data: 1313
# importing data: 1314
# importing data: 1315
# importing data: 1316
# importing data: 1317
# importing data: 1318
# importing data: 1319
# importing data: 1320
# importing data: 1321
# importing data: 1322
# importing data: 1323
# importing data: 1324
# importing data: 1325
# importing data: 1326
# importing data: 1327
# importing data: 1328
# importing data: 1329
# importing data: 1330
# importing data: 1331
# importing data: 1332
# importing data: 1333
# importing data: 1334
# importing data: 1335
# importing data: 1336
# importing data: 1337
# importing data: 1338
# importing data: 1339
# importing data: 1340
# importing data: 1341
# importing data: 1342
# importing data: 1343
# importing data: 1344
# importing data: 1516
# importing data: 1517
# importing data: 1518
# importing data: 1519
# importing data: 1520
# importing data: 1521
# importing data: 1522
# importing data: 1523
# importing data: 1524
# importing data: 1525
# importing data: 1526
# importing data: 1527
# importing data: 1528
# importing data: 1529
# importing data: 1530
# importing data: 1531
# importing data: 1532
# importing data: 1533
# importing data: 1534
# importing data: 1535
# importing data: 1536
# importing data: 1537
# importing data: 1538
# importing data: 1539
# importing data: 1540
# importing data: 1541
# importing data: 1542
# importing data: 1543
# importing data: 1544
# importing data: 1545
# importing data: 1546
# importing data: 1547
# importing data: 1548
# importing data: 1549
# importing data: 1550
# importing data: 1551
# importing data: 1552
# importing data: 1553
# importing data: 1554
# importing data: 1555
# importing data: 1556
# importing data: 1557
# importing data: 1558
# importing data: 1559
# importing data: 1560
# importing data: 1561
# importing data: 1562
# importing data: 1563
# importing data: 1564
# importing data: 1565
# importing data: 1566
# importing data: 1567
# importing data: 1568
# importing data: 1569
# importing data: 1570
# importing data: 1571
# importing data: 1572
# importing data: 1573
# importing data: 1574
# importing data: 1575
# importing data: 1576
# importing data: 1577
# importing data: 1578
# importing data: 1579
# importing data: 1580
# importing data: 1581
# importing data: 1582
# importing data: 1583
# importing data: 1584
# importing data: 1585
# importing data: 1586
# importing data: 1587
# importing data: 1588
# importing data: 1589
# importing data: 1590
# importing data: 1591
# importing data: 1592
# importing data: 1593
# importing data: 1594
# importing data: 1595
# importing data: 1596
# importing data: 1597
# importing data: 1598
# importing data: 1599
# importing data: 1600
# importing data: 1601
# importing data: 1602
# importing data: 1603
# importing data: 1604
# importing data: 1605
# importing data: 1606
# importing data: 1607
# importing data: 1608
# importing data: 1609
# importing data: 1610
# importing data: 1611
# importing data: 1612
# importing data: 1613
# importing data: 1614
# importing data: 1615
# importing data: 1616
# importing data: 1617
# importing data: 1618
# importing data: 1619
# importing data: 1620
# importing data: 1621
# importing data: 1622
# importing data: 1623
# importing data: 1624
# importing data: 1625
# importing data: 1626
# importing data: 1627
# importing data: 1628
# importing data: 1629
# importing data: 1630
# importing data: 1631
# importing data: 1632
# importing data: 1633
# importing data: 1634
# importing data: 1635
# importing data: 1636
# importing data: 1637
# importing data: 1638
# importing data: 1639
# importing data: 1640
# importing data: 1641
# importing data: 1642
# importing data: 1643
# importing data: 1644
# importing data: 1645
# importing data: 1646
# importing data: 1647
# importing data: 1648
# importing data: 1649
# importing data: 1650
# importing data: 1651
# importing data: 1652
# importing data: 1653
# importing data: 1654
# importing data: 1655
# importing data: 1656
# importing data: 1657
# importing data: 1658
# importing data: 1659
# importing data: 1660
# importing data: 1661
# importing data: 1662
# importing data: 1663
# importing data: 1664
# importing data: 1665
# importing data: 1666
# importing data: 1667
# importing data: 1668
# importing data: 1669
# importing data: 1670
# importing data: 1671
# importing data: 1672
# importing data: 1673
# importing data: 1674
# importing data: 1675
# importing data: 1676
# importing data: 1677
# importing data: 1678
# importing data: 1679
# importing data: 1680
# importing data: 1681
# importing data: 1682
# importing data: 1683
# importing data: 1684
# importing data: 1685
# importing data: 1857
# importing data: 1858
# importing data: 1859
# importing data: 1860
# importing data: 1861
# importing data: 1862
# importing data: 1863
# importing data: 1864
# importing data: 1865
# importing data: 1866
# importing data: 1867
# importing data: 1868
# importing data: 1869
# importing data: 1870
# importing data: 1871
# importing data: 1872
# importing data: 1873
# importing data: 1874
# importing data: 1875
# importing data: 1876
# importing data: 1877
# importing data: 1878
# importing data: 1879
# importing data: 1880
# importing data: 1881
# importing data: 1882
# importing data: 1883
# importing data: 1884
# importing data: 1885
# importing data: 1886
# importing data: 1887
# importing data: 1888
# importing data: 1889
# importing data: 1890
# importing data: 1891
# importing data: 1892
# importing data: 1893
# importing data: 1894
# importing data: 1895
# importing data: 1896
# importing data: 1897
# importing data: 1898
# importing data: 1899
# importing data: 1900
# importing data: 1901
# importing data: 1902
# importing data: 1903
# importing data: 1904
# importing data: 1905
# importing data: 1906
# importing data: 1907
# importing data: 1908
# importing data: 1909
# importing data: 1910
# importing data: 1911
# importing data: 1912
# importing data: 1913
# importing data: 1914
# importing data: 1915
# importing data: 1916
# importing data: 1917
# importing data: 1918
# importing data: 1919
# importing data: 1920
# importing data: 1921
# importing data: 1922
# importing data: 1923
# importing data: 1924
# importing data: 1925
# importing data: 1926
# importing data: 1927
# importing data: 1928
# importing data: 1929
# importing data: 1930
# importing data: 1931
# importing data: 1932
# importing data: 1933
# importing data: 1934
# importing data: 1935
# importing data: 1936
# importing data: 1937
# importing data: 1938
# importing data: 1939
# importing data: 1940
# importing data: 1941
# importing data: 1942
# importing data: 1943
# importing data: 1944
# importing data: 1945
# importing data: 1946
# importing data: 1947
# importing data: 1948
# importing data: 1949
# importing data: 1950
# importing data: 1951
# importing data: 1952
# importing data: 1953
# importing data: 1954
# importing data: 1955
# importing data: 1956
# importing data: 1957
# importing data: 1958
# importing data: 1959
# importing data: 1960
# importing data: 1961
# importing data: 1962
# importing data: 1963
# importing data: 1964
# importing data: 1965
# importing data: 1966
# importing data: 1967
# importing data: 1968
# importing data: 1969
# importing data: 1970
# importing data: 1971
# importing data: 1972
# importing data: 1973
# importing data: 1974
# importing data: 1975
# importing data: 1976
# importing data: 1977
# importing data: 1978
# importing data: 1979
# importing data: 1980
# importing data: 1981
# importing data: 1982
# importing data: 1983
# importing data: 1984
# importing data: 1985
# importing data: 1986
# importing data: 1987
# importing data: 1988
# importing data: 1989
# importing data: 1990
# importing data: 1991
# importing data: 1992
# importing data: 1993
# importing data: 1994
# importing data: 1995
# importing data: 1996
# importing data: 1997
# importing data: 1998
# importing data: 1999
# importing data: 2000
# importing data: 2001
# importing data: 2002
# importing data: 2003
# importing data: 2004
# importing data: 2005
# importing data: 2006
# importing data: 2007
# importing data: 2008
# importing data: 2009
# importing data: 2010
# importing data: 2011
# importing data: 2012
# importing data: 2013
# importing data: 2014
# importing data: 2015
# importing data: 2016
# importing data: 2017
# importing data: 2018
# importing data: 2019
# importing data: 2020
# importing data: 2021
# importing data: 2022
# importing data: 2023
# importing data: 2024
# importing data: 2025
# importing data: 2026
# importing data: 2027
# importing data: 2028
# importing data: 2029
# importing data: 2030
# importing data: 2031
# importing data: 2032
# importing data: 2033
# importing data: 2034
# importing data: 2035
# importing data: 2036
# importing data: 2037
# importing data: 2038
# importing data: 2039
# importing data: 2040
# importing data: 2041
# importing data: 2042
# importing data: 2043
# importing data: 2044
# importing data: 2045
# importing data: 2046
# importing data: 2047
# importing data: 2048
# importing data: 2049
# importing data: 2050
# importing data: 2051
# importing data: 2052
# importing data: 2053
# importing data: 2054
# importing data: 2055
# importing data: 2056
# importing data: 2057
# importing data: 2058
# importing data: 2059
# importing data: 2060
# importing data: 2061
# importing data: 2062
# importing data: 2063
# importing data: 2064
# importing data: 2065
# importing data: 2066
# importing data: 2067
# importing data: 2068
# importing data: 2069
# importing data: 2070
# importing data: 2071
# importing data: 2072
# importing data: 2073
# importing data: 2074
# importing data: 2075
# importing data: 2076
# importing data: 2077
# importing data: 2078
# importing data: 2079
# importing data: 2080
# importing data: 2081
# importing data: 2082
# importing data: 2083
# importing data: 2084
# importing data: 2085
# importing data: 2086
# importing data: 2087
# importing data: 2088
# importing data: 2089
# importing data: 2090
# importing data: 2091
# importing data: 2092
# importing data: 2093
# importing data: 2094
# importing data: 2095
# importing data: 2096
# importing data: 2097
# importing data: 2098
# importing data: 2099
# importing data: 2100
# importing data: 2101
# importing data: 2102
# importing data: 2103
# importing data: 2104
# importing data: 2105
# importing data: 2106
# importing data: 2107
# importing data: 2108
# importing data: 2109
# importing data: 2110
# importing data: 2111
# importing data: 2112
# importing data: 2113
# importing data: 2114
# importing data: 2115
# importing data: 2116
# importing data: 2117
# importing data: 2118
# importing data: 2119
# importing data: 2120
# importing data: 2121
# importing data: 2122
# importing data: 2123
# importing data: 2124
# importing data: 2125
# importing data: 2126
# importing data: 2127
# importing data: 2128
# importing data: 2129
# importing data: 2130
# importing data: 2131
# importing data: 2132
# importing data: 2133
# importing data: 2134
# importing data: 2135
# importing data: 2136
# importing data: 2137
# importing data: 2138
# importing data: 2139
# importing data: 2140
# importing data: 2141
# importing data: 2142
# importing data: 2143
# importing data: 2144
# importing data: 2145
# importing data: 2146
# importing data: 2147
# importing data: 2148
# importing data: 2149
# importing data: 2150
# importing data: 2151
# importing data: 2152
# importing data: 2153
# importing data: 2154
# importing data: 2155
# importing data: 2156
# importing data: 2157
# importing data: 2158
# importing data: 2159
# importing data: 2160
# importing data: 2161
# importing data: 2162
# importing data: 2163
# importing data: 2164
# importing data: 2165
# importing data: 2166
# importing data: 2167
# importing data: 2168
# importing data: 2169
# importing data: 2170
# importing data: 2171
# importing data: 2172
# importing data: 2173
# importing data: 2174
# importing data: 2175
# importing data: 2176
# importing data: 2177
# importing data: 2178
# importing data: 2179
# importing data: 2180
# importing data: 2181
# importing data: 2182
# importing data: 2183
# importing data: 2184
# importing data: 2185
# importing data: 2186
# importing data: 2187
# importing data: 2188
# importing data: 2189
# importing data: 2190
# importing data: 2191
# importing data: 2192
# importing data: 2193
# importing data: 2194
# importing data: 2195
# importing data: 2196
# importing data: 2197
# importing data: 2198
# importing data: 2199
# importing data: 2200
# importing data: 2201
# importing data: 2202
# importing data: 2203
# importing data: 2204
# importing data: 2205
# importing data: 2206
# importing data: 2207
# importing data: 2208
# importing data: 2209
# importing data: 2210
# importing data: 2211
# importing data: 2212
# importing data: 2213
# importing data: 2214
# importing data: 2215
# importing data: 2216
# importing data: 2217
# importing data: 2218
# importing data: 2219
# importing data: 2220
# importing data: 2221
# importing data: 2222
# importing data: 2223
# importing data: 2224
# importing data: 2225
# importing data: 2226
# importing data: 2227
# importing data: 2228
# importing data: 2229
# importing data: 2230
# importing data: 2231
# importing data: 2232
# importing data: 2233
# importing data: 2234
# importing data: 2235
# importing data: 2236
# importing data: 2237
# importing data: 2238
# importing data: 2239
# importing data: 2240
# importing data: 2241
# importing data: 2242
# importing data: 2243
# importing data: 2244
# importing data: 2245
# importing data: 2246
# importing data: 2247
# importing data: 2248
# importing data: 2249
# importing data: 2250
# importing data: 2251
# importing data: 2252
# importing data: 2253
# importing data: 2254
# importing data: 2255
# importing data: 2256
# importing data: 2257
# importing data: 2258
# importing data: 2259
# importing data: 2260
# importing data: 2261
# importing data: 2262
# importing data: 2263
# importing data: 2264
# importing data: 2265
# importing data: 2266
# importing data: 2267
# importing data: 2268
# importing data: 2269
# importing data: 2270
# importing data: 2271
# importing data: 2272
# importing data: 2273
# importing data: 2274
# importing data: 2275
# importing data: 2276
# importing data: 2277
# importing data: 2278
# importing data: 2279
# importing data: 2280
# importing data: 2281
# importing data: 2282
# importing data: 2283
# importing data: 2284
# importing data: 2285
# importing data: 2286
# importing data: 2287
# importing data: 2288
# importing data: 2289
# importing data: 2290
# importing data: 2291
# importing data: 2292
# importing data: 2293
# importing data: 2294
# importing data: 2295
# importing data: 2296
# importing data: 2297
# importing data: 2298
# importing data: 2299
# importing data: 2300
# importing data: 2301
# importing data: 2302
# importing data: 2303
# importing data: 2304
# importing data: 2305
# importing data: 2306
# importing data: 2307
# importing data: 2308
# importing data: 2309
# importing data: 2310
# importing data: 2311
# importing data: 2312
# importing data: 2313
# importing data: 2314
# importing data: 2315
# importing data: 2316
# importing data: 2317
# importing data: 2318
# importing data: 2319
# importing data: 2320
# importing data: 2321
# importing data: 2322
# importing data: 2323
# importing data: 2324
# importing data: 2325
# importing data: 2326
# importing data: 2327
# importing data: 2328
# importing data: 2329
# importing data: 2330
# importing data: 2331
# importing data: 2332
# importing data: 2333
# importing data: 2334
# importing data: 2335
# importing data: 2336
# importing data: 2337
# importing data: 2338
# ...
# importing data: 38835
# importing data: 38836
# importing data: 38837
# importing data: 38838
# importing data: 38839
# importing data: 38840
# importing data: 38841
# importing data: 38842
# importing data: 38843
# importing data: 38844
# importing data: 38845
# importing data: 38846
# importing data: 38847
# importing data: 38848
# importing data: 38849
# importing data: 38850
# importing data: 38851
# importing data: 38852
# importing data: 38853
# importing data: 38854
# importing data: 38855
# importing data: 38856
# importing data: 38857
# importing data: 38858
# importing data: 38859
# importing data: 38860
# importing data: 38861
# importing data: 38862
# importing data: 38863
# importing data: 39546
# importing data: 39547
# importing data: 39548
# importing data: 39549
# importing data: 39550
# importing data: 39551
# importing data: 39552
# importing data: 39553
# importing data: 39554
# importing data: 39555
# importing data: 39556
# importing data: 39557
# importing data: 39558
# importing data: 39559
# importing data: 39560
# importing data: 39561

# %% [markdown]
# # Test run vector store

# %%
# Test that all data has loaded – get object count
result = (
    client.query.aggregate("Comments")
    .with_fields("meta { count }")
    .do()
)
print("Object count: ", result["data"]["Aggregate"]["Comments"], "\n")
# Out:
# Object count:  [{'meta': {'count': 39561}}]

# %%
# Find one entry
test_comment = (
    client.query
    .get("Comments", ["comment", "core_identity_groups", "sub_identity_groups"])
    .with_limit(1)
    .do()
)["data"]["Get"]["Comments"][0]

print(test_comment['comment'])
print(test_comment['core_identity_groups'])
print(test_comment['sub_identity_groups'])
# Out:
# Lesbian Butch should play soccer and keep her worthless political comments to herself,looks like a crusty ass looking shrimp boat captain.. just like her I couldn't refrain from my shity ass comments too
# ['sexuality']
# ['lesbian']

# %%
# query with relevancy score 
def query_weaviate(query, collection_name):
    
    nearText = {
        "concepts": [query],
        "distance": 0.7,
    }

    properties = [
        "comment", "core_identity", "sub_identity",
        # "_additional {certainty distance}"
    ]

    result = (
        client.query
        .get(collection_name, properties)
        .with_near_text(nearText)
        .with_limit(10)
        .do()
    )
    
    # Check for errors
    if ("errors" in result):
        print ("\033[91mYou probably have run out of OpenAI API calls for the current minute – the limit is set at 60 per minute.")
        raise Exception(result["errors"][0]['message'])
    
    return result["data"]["Get"][collection_name]

# %%
query_result = query_weaviate("I hate chinese and malays they are pigs!", "DataClass")

# %%
print(json.dumps(query_result, indent=4))
# Out:
# [
#     {
#         "comment": "Annihilate the chinese government please. They are inbred retards and shouldn't be able to call themselves, human fucking pigs..",
#         "core_identity": [
#             "origin"
#         ],
#         "sub_identity": [
#             "specific country"
#         ]
#     },
#     {
#         "comment": "Fucking racist pigs.",
#         "core_identity": [
#             "race"
#         ],
#         "sub_identity": [
#             "other"
#         ]
#     },
#     {
#         "comment": "Man Chinese people are the worst",
#         "core_identity": [
#             "race"
#         ],
#         "sub_identity": [
#             "asian"
#         ]
#     },
#     {
#         "comment": "I dislike most malays cause they're judgemental",
#         "core_identity": [
#             "race",
#             "origin"
#         ],
#         "sub_identity": [
#             "asian",
#             "specific country"
#         ]
#     },
#     {
#         "comment": "Fuck China. Bunch of hosers.",
#         "core_identity": [
#             "origin"
#         ],
#         "sub_identity": [
#             "specific country"
#         ]
#     },
#     {
#         "comment": "Good, fuck the Chinese",
#         "core_identity": [
#             "origin"
#         ],
#         "sub_identity": [
#             "specific country"
#         ]
#     },
#     {
#         "comment": "Fuck chinks",
#         "core_identity": [
#             "race"
#         ],
#         "sub_identity": [
#             "asian"
#         ]
#     },
#     {
#         "comment": "Screw the Chinese",
#         "core_identity": [
#             "origin"
#         ],
#         "sub_identity": [
#             "specific country"
#         ]
#     },
#     {
#         "comment": "Burn them I say That rattles the filthy Pakistani pigs",
#         "core_identity": [
#             "race",
#             "religion",
#             "origin"
#         ],
#         "sub_identity": [
#             "middle eastern",
#             "muslim",
#             "other",
#             "specific country"
#         ]
#     },
#     {
#         "comment": "Africans.... gross. I hope China wipes all of these nasty kni ggers out.",
#         "core_identity": [
#             "race",
#             "origin"
#         ],
#         "sub_identity": [
#             "asian",
#             "black",
#             "specific country"
#         ]
#     }
# ]

# %%
# Write JSON data to a file
with open("test.json", "w") as json_file:
    json.dump(query_result, json_file, indent=4)

# %%
for i, v in enumerate(query_result):
    print(f"{i+1}. { v['comment']} (Score: {round(v['_additional']['certainty'],3) })")
# Out:
# 1. God I hate Americans (Score: 0.94)
# 2. Canadians are just snow Mexicans (Score: 0.938)
# 3. Of course it's the Americans that always running to Canada and they hate Americans. (Score: 0.937)
# 4. No Canadians wtf... you racist fuck go die in a hole... stupid bitch (Score: 0.936)
# 5. I hate people of color (Score: 0.928)
# 6. *I hate fucking minorities (Score: 0.927)
# 7. Kick Canadian poor business and their citizens out of U.S. soil! (Score: 0.926)
# 8. You Canadicunts deserve to be raped and killed for being weak (Score: 0.926)
# 9. I hate minorities too (Score: 0.926)
# 10. I hate atheists (Score: 0.925)

# %%
prompt_template = """
You are a professional, specialised in reviewing abusive content which could violate sections 298 and 298A of Singapore's penal code.

Section 298 of the Penal Code is a charge for uttering words, etc., with deliberate intent to wound the religious or racial feelings of any person.
Section 298A of the Penal Code is a charge for promoting enmity between different groups on grounds of religion or race or doing acts prejudicial to maintenance of harmony.
Hate speech has been defined as all forms of expression which spread, incite, promote, or justify racial hatred, xenophobia, or other forms of hatred based on intolerance.

Your instruction is to first evaluate if the query at the end is considered a hate speech or not. 
Secondly, identify the possible core identity groups and the sub identity groups.

Use the following pieces of context to answer the query. If you don't know the answer, just say that you don't know, don't try to make up an answer.

Query: Does the following comment:{query} violate sections 298 and 298A of Singapore's penal code? Answer 'Yes' or 'No'.
Core targeted identity groups: [answer here]
Sub targeted identity groups: [answer here]
Begin!

Context:
---------
{result}
---------
Query: {query}
Answer:"""

# %%
hatespeech_template= """
You are a professional, specialised in reviewing abusive content which could violate sections 298 and 298A of Singapore's penal code.
Section 298 of the Penal Code is a charge for uttering words, etc., with deliberate intent to wound the religious or racial feelings of any person.
Section 298A of the Penal Code is a charge for promoting enmity between different groups on grounds of religion or race or doing acts prejudicial to maintenance of harmony.
Hate speech has been defined as all forms of expression which spread, incite, promote, or justify racial hatred, xenophobia, or other forms of hatred based on intolerance.
Your instruction is to first evaluate if the comment at the end is considered a hate speech or not. Secondly, identify the possible core identity groups and the sub identity groups.
Use only the context given below to carry out the task. If you don't know the answer, just say you don't know the answer.

Here is the context:
{context}

Here is the comment:
{question}
"""

# %%
# generative query (grouped)
def generative_search_group(query, collection_name):
    generateTask = hatespeech_template
    result = (
        client.query
        .get(collection_name, ["comment", "core_identity", "sub_identity"])
        .with_near_text({ "concepts": [query], "distance": 0.7 })
        .with_generate(grouped_task=generateTask)
        .with_limit(3)
        .do()
    )
    
    # Check for errors
    if ("errors" in result):
        raise Exception(result["errors"][0]['message'])
    
    return result["data"]["Get"][collection_name]

# %%
query_result = generative_search_group("I hate chinese and malays they are pigs!", "DataClass")

print(query_result[0]['_additional']['generate']['groupedResult'])
# print(json.dumps(query_result, indent=4))
# Out:
# Based on the given context, the comment "Annihilate the Chinese government please. They are inbred retards and shouldn't be able to call themselves, human fucking pigs.." can be considered hate speech. It spreads, incites, and promotes racial hatred and derogatory language towards the Chinese people.
#
# Possible core identity group: Chinese people
# Possible sub-identity groups: Chinese government, Chinese individuals
#
# The comment "Fucking racist pigs." can also be considered hate speech as it uses derogatory language and promotes hatred based on race.
#
# Possible core identity group: Unspecified
# Possible sub-identity groups: Unspecified
#
# The comment "Man Chinese people are the worst" can be seen as derogatory and offensive, but it does not explicitly incite or promote hatred. It may be considered disrespectful or offensive, but it does not meet the criteria of hate speech as defined.
#
# Possible core identity group: Chinese people
# Possible sub-identity groups: Unspecified

# %%
id = "00000ff7-fe6c-45e5-91b8-be1a19a0c393"

data_object = client.data_object.get_by_id(
    uuid=id,
    class_name='Comments',
)

print(json.dumps(data_object, indent=2))
# Out:
# {
#   "class": "Comments",
#   "creationTimeUnix": 1695966794924,
#   "id": "00000ff7-fe6c-45e5-91b8-be1a19a0c393",
#   "lastUpdateTimeUnix": 1695966794924,
#   "properties": {
#     "comment": "Lesbian Butch should play soccer and keep her worthless political comments to herself,looks like a crusty ass looking shrimp boat captain.. just like her I couldn't refrain from my shity ass comments too",
#     "core_identity_groups": [
#       "sexuality"
#     ],
#     "sub_identity_groups": [
#       "lesbian"
#     ]
#   },
#   "vectorWeights": null
# }

# %%
# Semantic search
response = (
    client.query
    .get("Comments", ["comment", "core_identity_groups", "sub_identity_groups"])
    .with_near_text({"concepts": ["I hate Singaporeans"]})
    .with_additional(["id", "vector"])
    .with_limit(1)
    .do()
)

print(json.dumps(response, indent=4))
# Out:
# {
#     "data": {
#         "Get": {
#             "Comments": [
#                 {
#                     "_additional": {
#                         "id": "91197a4c-12a3-446d-bd51-8f4eefe9d7dd",
#                         "vector": [
#                             -0.013833661,
#                             -0.0050428594,
#                             -0.016684387,
#                             -0.023887563,
#                             -0.014253634,
#                             0.01879698,
#                             -0.009506665,
#                             0.017957034,
#                             -0.012955535,
#                             -0.013719123,
#                             0.016595302,
#                             0.00813857,
#                             0.003337514,
#                             -0.011663799,
#                             -0.004797875,
#                             0.026471034,
#                             0.04948047,
#                             -0.01142836,
#                             0.032070678,
#                             -0.013986378,
#                             -0.008991243,
#                             0.041284632,
#                             -0.0070886374,
#                             0.0020521416,
#                             0.009303042,
#                             0.00083199225,
#                             0.0048837787,
#                             -0.030288972,
#                             0.021558622,
#                             -0.023785751,
#                             -0.0024975676,
#                             -0.016455311,
#                             -0.014673607,
#                             -0.015360836,
#                             -0.0031593435,
#                             -0.018847886,
#                             -0.029398121,
#                             -0.014609975,
#                             -0.005179669,
#                             -0.021520441,
#                             0.008933974,
#                             -0.016773473,
#                             0.013197338,
#                             -0.009678472,
#                             -0.011072019,
#                             0.018351553,
#                             -0.01566627,
#                             -0.022347663,
#                             -0.029347215,
#                             0.019853275,
#                             0.009729378,
#                             -0.0028380004,
#                             -0.013171885,
#                             -0.018109752,
#                             0.015513553,
#                             0.023340326,
#                             -0.034437798,
#                             0.0071586333,
#                             0.0034997761,
#                             -0.023556676,
#                             0.008348557,
#                             0.022487653,
#                             -0.0379503,
#                             0.0005174101,
#                             -0.015144486,
#                             -0.0016767109,
#                             0.012230127,
#                             0.00922032,
#                             -0.014597248,
#                             -0.0038656618,
#                             0.022220397,
#                             0.034437798,
#                             -0.010862033,
#                             -0.0200569,
#                             0.011460177,
#                             0.0031832056,
#                             -0.011676526,
#                             -0.019382397,
#                             -0.007012279,
#                             -0.013808208,
#                             0.043906283,
#                             -0.012191948,
#                             0.0066686645,
#                             0.019738737,
#                             0.005676001,
#                             0.0105502345,
#                             -0.025300201,
#                             0.0111420145,
#                             0.005501012,
#                             -0.039197493,
#                             -0.009716651,
#                             0.013235517,
#                             0.005357839,
#                             0.031408902,
#                             -0.023633035,
#                             0.00010240822,
#                             0.014419078,
#                             0.01247193,
#                             -0.0055041933,
#                             -0.037670318,
#                             0.024218451,
#                             -0.0023082616,
#                             -0.01922968,
#                             -0.017537061,
#                             -0.0018405641,
#                             0.0015168348,
#                             -0.014851778,
#                             -0.016468037,
#                             -0.00060172286,
#                             -0.029601743,
#                             0.0110083865,
#                             -0.01304462,
#                             0.0026200598,
#                             -0.05401109,
#                             -0.0126501005,
#                             -0.0041742786,
#                             -0.005895532,
#                             -0.00204896,
#                             -0.012611921,
#                             -0.0405465,
#                             0.006315505,
#                             0.01408819,
#                             0.02206768,
#                             0.0046769734,
#                             0.019318765,
#                             -0.012281033,
#                             -0.008265835,
#                             -0.00044820996,
#                             -0.03000899,
#                             0.009048512,
#                             0.036397673,
#                             -0.0015049038,
#                             0.017829768,
#                             -0.0009338039,
#                             -0.015831714,
#                             0.026114693,
#                             -0.019878728,
#                             0.05289116,
#                             -0.020718675,
#                             -0.0069740997,
#                             0.0074577047,
#                             0.02415482,
#                             0.0057841754,
#                             0.003922931,
#                             -0.013719123,
#                             0.02652194,
#                             -0.0020378241,
#                             -0.010811127,
#                             0.019127868,
#                             -0.004947411,
#                             -0.0034902312,
#                             0.0043651755,
#                             0.027463699,
#                             -0.0092839515,
#                             -0.0064554964,
#                             0.011676526,
#                             0.00031179824,
#                             0.015055401,
#                             0.00092187285,
#                             -0.0053482945,
#                             -0.0032070677,
#                             -0.01674802,
#                             0.013171885,
#                             -0.026471034,
#                             0.004435171,
#                             0.008863979,
#                             0.014075464,
#                             0.023047617,
#                             0.0016130786,
#                             -0.013719123,
#                             0.019318765,
#                             0.015806261,
#                             -0.011714705,
#                             0.002981173,
#                             0.0025246113,
#                             0.007623149,
#                             0.002056914,
#                             0.028125474,
#                             -0.03209613,
#                             0.009678472,
#                             -0.019522388,
#                             0.040190157,
#                             0.037848487,
#                             0.024625698,
#                             -0.0017117087,
#                             0.018618809,
#                             0.026700111,
#                             -0.016073518,
#                             0.033979647,
#                             -0.011975598,
#                             0.019127868,
#                             0.012891903,
#                             -0.00571418,
#                             -0.01566627,
#                             -0.6442643,
#                             -0.040011987,
#                             0.005179669,
#                             0.01343914,
#                             0.001883516,
#                             0.019000603,
#                             0.022373116,
#                             0.019038783,
#                             -0.01757524,
#                             0.0018214744,
#                             0.0004326996,
#                             0.0163535,
#                             0.0010316386,
#                             -0.02106229,
#                             0.0058128103,
#                             -0.013757302,
#                             0.013808208,
#                             -0.054672867,
#                             0.0014142278,
#                             0.020693222,
#                             -0.005688727,
#                             0.00815766,
#                             0.0017737502,
#                             -0.023263967,
#                             0.012605557,
#                             0.00896579,
#                             -0.010111172,
#                             -0.003814756,
#                             -0.01062023,
#                             0.017867949,
#                             -0.030899841,
#                             0.026547393,
#                             -0.013019168,
#                             -0.03306334,
#                             0.061188813,
#                             0.0016703478,
#                             -0.0029875361,
#                             0.021660432,
#                             0.0103657,
#                             0.025198389,
#                             -0.020985931,
#                             0.004333359,
#                             -0.0019439666,
#                             -0.018262468,
#                             0.0057682674,
#                             -0.015831714,
#                             -0.0022319027,
#                             -0.013388235,
#                             0.02037506,
#                             0.0014961543,
#                             0.0007779048,
#                             0.029729009,
#                             -0.005720543,
#                             0.01391002,
#                             0.0015542188,
#                             0.010995661,
#                             -0.0055614626,
#                             0.011097472,
#                             0.013668217,
#                             -0.0075658797,
#                             -0.025656542,
#                             0.0073368037,
#                             -0.007037732,
#                             0.022945805,
#                             -0.01911514,
#                             -0.001808748,
#                             -0.016595302,
#                             -0.0036461304,
#                             0.02001872,
#                             -0.018949697,
#                             0.009894822,
#                             0.021762244,
#                             -0.020260522,
#                             0.015119033,
#                             0.0005639412,
#                             0.019420575,
#                             0.018351553,
#                             -0.023493042,
#                             -0.0021762245,
#                             -0.014100917,
#                             -0.001643304,
#                             0.009086692,
#                             -0.01692619,
#                             0.010868396,
#                             0.03540501,
#                             0.011129288,
#                             -0.009487575,
#                             -0.0030575318,
#                             0.007012279,
#                             -0.0055582807,
#                             0.0027377794,
#                             0.033597853,
#                             -0.0029414028,
#                             0.008119481,
#                             0.010002997,
#                             -0.0073940726,
#                             -0.031383447,
#                             -0.0031577526,
#                             0.016671661,
#                             0.022843994,
#                             0.008113118,
#                             0.015768083,
#                             0.0014492255,
#                             -0.008100391,
#                             -0.006509584,
#                             0.010512055,
#                             -0.02512203,
#                             0.025007492,
#                             0.022882173,
#                             -0.043117244,
#                             -0.0020760037,
#                             0.0016623937,
#                             -0.006993189,
#                             -0.0044288076,
#                             -0.012720096,
#                             -0.02167316,
#                             -0.0023432593,
#                             -0.0045210747,
#                             -0.0030161708,
#                             -0.034056004,
#                             0.0072031757,
#                             0.01922968,
#                             0.018173384,
#                             -0.015080853,
#                             0.00934122,
#                             0.02264037,
#                             -0.021724066,
#                             -0.03364876,
#                             -0.025058398,
#                             0.014711786,
#                             0.008113118,
#                             0.023251241,
#                             0.004699245,
#                             -0.013922746,
#                             0.021202281,
#                             0.012198311,
#                             0.013744576,
#                             -0.005526465,
#                             0.018453365,
#                             -0.025923796,
#                             -0.035099573,
#                             0.00011781917,
#                             0.0027807313,
#                             -0.0104675125,
#                             -0.006003707,
#                             -0.002484841,
#                             -0.00510331,
#                             -0.006417317,
#                             0.013922746,
#                             0.0018342009,
#                             0.004864689,
#                             -0.00025452918,
#                             -0.022602191,
#                             -0.005450106,
#                             -0.0042506373,
#                             -0.017257078,
#                             -0.0014905866,
#                             -0.014100917,
#                             -0.028990874,
#                             -0.014889956,
#                             0.023047617,
#                             0.032757904,
#                             0.0028952693,
#                             -0.0064554964,
#                             -0.011937418,
#                             -0.024765689,
#                             0.0029270856,
#                             0.013120979,
#                             -0.026700111,
#                             -0.015806261,
#                             0.015831714,
#                             0.0056219134,
#                             0.0032484287,
#                             0.008863979,
#                             0.0049155946,
#                             0.01879698,
#                             -0.006439588,
#                             -0.009742104,
#                             -0.011969235,
#                             -0.0044860765,
#                             0.0156153655,
#                             0.008991243,
#                             -0.021138648,
#                             0.004333359,
#                             0.022016773,
#                             -0.016188055,
#                             0.013375509,
#                             0.000470879,
#                             -0.012726459,
#                             -0.0051733055,
#                             0.013528226,
#                             0.007406799,
#                             -0.006764113,
#                             -0.01241466,
#                             -0.008017669,
#                             0.0024291629,
#                             0.019267859,
#                             0.014164548,
#                             -0.006458678,
#                             0.004549709,
#                             -0.0022971258,
#                             -0.007903131,
#                             0.022284029,
#                             0.014953589,
#                             0.029449025,
#                             -0.020833213,
#                             -0.0040215612,
#                             -0.025440192,
#                             0.021533169,
#                             0.023340326,
#                             0.0071395435,
#                             -0.0030829846,
#                             -0.008838526,
#                             0.0050492226,
#                             -0.0072604446,
#                             0.009602114,
#                             0.018237015,
#                             0.028430909,
#                             0.01263101,
#                             -0.0008956246,
#                             -0.012478293,
#                             -0.008144934,
#                             0.012796454,
#                             0.00022151992,
#                             -0.009983907,
#                             -0.0151572125,
#                             -0.010416606,
#                             -0.010015723,
#                             0.023123976,
#                             -0.013591858,
#                             -0.026114693,
#                             -0.02350577,
#                             -0.0044288076,
#                             0.0025627906,
#                             0.013986378,
#                             0.0068404716,
#                             0.015577186,
#                             0.0006251873,
#                             0.033470586,
#                             -0.019738737,
#                             0.013426414,
#                             -0.014266361,
#                             0.030492596,
#                             -0.019662378,
#                             -0.008132207,
#                             -0.009481212,
#                             0.026267411,
#                             -0.008437642,
#                             -0.012484656,
#                             0.018733347,
#                             0.004890142,
#                             0.016658934,
#                             -0.008068575,
#                             0.016735293,
#                             0.014469984,
#                             -0.024982039,
#                             0.031256184,
#                             -0.004820146,
#                             0.025312927,
#                             0.024880227,
#                             0.020782307,
#                             -0.007018642,
#                             0.016480764,
#                             -0.0046801553,
#                             -0.00859036,
#                             0.021138648,
#                             0.010123898,
#                             0.0016973915,
#                             -0.0071968124,
#                             -0.0032468378,
#                             -0.025758352,
#                             -0.024231177,
#                             0.009073965,
#                             -0.016468037,
#                             0.014062737,
#                             0.01369367,
#                             0.016760746,
#                             0.0010539099,
#                             0.008246745,
#                             -0.001387184,
#                             -0.0014762692,
#                             -0.030161707,
#                             0.005978254,
#                             0.003592043,
#                             -0.010779311,
#                             -0.012185585,
#                             -0.010556597,
#                             -0.020909572,
#                             -0.013426414,
#                             0.023085797,
#                             -0.0025214297,
#                             0.02642013,
#                             -0.016798927,
#                             0.0149154095,
#                             0.011791064,
#                             -0.0031816147,
#                             0.028863609,
#                             -0.014889956,
#                             0.002791867,
#                             0.005672819,
#                             0.032605186,
#                             -0.008106754,
#                             -0.013464593,
#                             -0.010480239,
#                             0.012764638,
#                             0.015500827,
#                             -0.0042506373,
#                             -0.02364576,
#                             0.017409796,
#                             -0.012675553,
#                             -0.008024032,
#                             -0.004527438,
#                             -0.027998209,
#                             0.03823028,
#                             -0.009901185,
#                             -0.009837553,
#                             -0.047775127,
#                             0.00083994627,
#                             0.029881725,
#                             0.002725053,
#                             -0.026394676,
#                             -0.008380373,
#                             -0.017486155,
#                             -0.016417133,
#                             0.11219646,
#                             0.0031625251,
#                             0.00084790034,
#                             0.015475374,
#                             -0.017015275,
#                             0.0021953143,
#                             -0.014037284,
#                             -0.029423572,
#                             0.01101475,
#                             -0.015678998,
#                             0.00920123,
#                             -0.0002811752,
#                             0.023162154,
#                             0.0034075093,
#                             0.013171885,
#                             0.012281033,
#                             0.0050333147,
#                             -0.0040247426,
#                             -0.010874759,
#                             -0.003006626,
#                             -0.029499931,
#                             -0.012325576,
#                             0.007107727,
#                             0.025631089,
#                             0.0183261,
#                             0.014266361,
#                             -0.0004891733,
#                             -0.0020266885,
#                             0.0065541263,
#                             -0.0207314,
#                             -0.00082562905,
#                             -0.010722042,
#                             -0.004228366,
#                             -0.015182666,
#                             0.023263967,
#                             0.016646208,
#                             0.0002909189,
#                             0.0023734847,
#                             0.033572398,
#                             -0.014889956,
#                             0.028659986,
#                             0.020171437,
#                             -0.0041997316,
#                             -0.021138648,
#                             0.018504271,
#                             -0.027692774,
#                             -0.010855669,
#                             0.012510109,
#                             -0.0036524937,
#                             -0.014533616,
#                             0.019776918,
#                             -0.021482263,
#                             0.011593804,
#                             -0.029092684,
#                             -0.015017222,
#                             0.022258576,
#                             -0.02220767,
#                             0.0077313236,
#                             -0.01000936,
#                             -0.004307906,
#                             -0.012987351,
#                             -0.025172936,
#                             0.021036837,
#                             -0.016442586,
#                             -0.009551208,
#                             -0.048996866,
#                             -0.028278193,
#                             -0.004871052,
#                             -0.014329993,
#                             -0.026903734,
#                             0.016989823,
#                             -0.03899387,
#                             -0.008564907,
#                             0.0058987136,
#                             0.018784253,
#                             0.01263101,
#                             0.01588262,
#                             -0.014190001,
#                             0.014737239,
#                             0.009939364,
#                             0.016646208,
#                             -0.0060927924,
#                             0.014444531,
#                             -0.0103657,
#                             -0.005077857,
#                             0.0027568692,
#                             0.0007174541,
#                             0.009678472,
#                             -0.0063250503,
#                             -0.00014545945,
#                             0.01326097,
#                             -0.022513106,
#                             -0.0008447187,
#                             0.007190449,
#                             0.008545817,
#                             -0.029805366,
#                             0.019280585,
#                             -0.0070950007,
#                             -0.013171885,
#                             -0.0040915566,
#                             0.013630037,
#                             -0.03456506,
#                             -0.0020712311,
#                             -0.0024737054,
#                             0.028074568,
#                             0.032859717,
#                             0.015717177,
#                             0.0064141355,
#                             -0.011587441,
#                             -0.014469984,
#                             0.010849306,
#                             -0.03403055,
#                             -0.031027107,
#                             -0.034056004,
#                             0.020107806,
#                             0.017269805,
#                             -0.020171437,
#                             0.009462122,
#                             0.010906575,
#                             0.004699245,
#                             -0.016722567,
#                             0.007018642,
#                             0.015386289,
#                             0.014851778,
#                             0.008628539,
#                             0.025363833,
#                             -0.020425966,
#                             -0.018300649,
#                             -0.0059750723,
#                             -0.023454864,
#                             -0.023251241,
#                             0.015513553,
#                             -0.009837553,
#                             0.0057682674,
#                             -0.018746074,
#                             -0.007871315,
#                             -0.021787697,
#                             0.019789644,
#                             -0.027718227,
#                             -0.009837553,
#                             -0.013210065,
#                             -0.015169939,
#                             -0.019458756,
#                             -0.023302145,
#                             -0.029703556,
#                             -0.038612075,
#                             -0.009112145,
#                             -0.009532117,
#                             -0.0074386154,
#                             0.019178774,
#                             -0.0083676465,
#                             -0.0068913773,
#                             -0.0019439666,
#                             0.00070552307,
#                             -0.025834711,
#                             -0.023836657,
#                             -0.036499485,
#                             -0.0016496673,
#                             0.010989297,
#                             0.027158264,
#                             0.023022164,
#                             -0.017346164,
#                             0.034794137,
#                             0.025223842,
#                             0.027336434,
#                             -0.011810154,
#                             0.013362782,
#                             -0.0322743,
#                             -0.011409271,
#                             0.012592831,
#                             0.012751912,
#                             0.0019519207,
#                             0.016213508,
#                             -0.0054310164,
#                             0.008329467,
#                             -0.010295705,
#                             0.015182666,
#                             -0.004559254,
#                             -0.012955535,
#                             0.017727958,
#                             0.008991243,
#                             -0.010448422,
#                             -0.013579132,
#                             0.0050396775,
#                             -0.010932028,
#                             -0.036397673,
#                             0.013025531,
#                             -0.0039102044,
#                             0.023989376,
#                             -0.025211114,
#                             0.009544844,
#                             -0.006713207,
#                             0.014533616,
#                             -0.012637374,
#                             0.016060792,
#                             -0.030696219,
#                             0.0058732606,
#                             0.02342941,
#                             -0.013337329,
#                             0.030568954,
#                             0.036219504,
#                             0.008685809,
#                             -0.048131466,
#                             -0.01164471,
#                             0.0012957125,
#                             0.010461149,
#                             -0.018415187,
#                             0.0072031757,
#                             0.00014337151,
#                             -0.035354104,
#                             0.0044892584,
#                             -0.026241958,
#                             -0.014050011,
#                             -0.013680943,
#                             0.009143961,
#                             -0.009710288,
#                             0.0024243905,
#                             0.0013163931,
#                             -0.025032945,
#                             -0.048233278,
#                             -0.01749888,
#                             -0.0023098523,
#                             0.02307307,
#                             -0.0019901,
#                             0.005128763,
#                             0.010588414,
#                             -0.0074513415,
#                             -0.00671957,
#                             0.028405456,
#                             -0.0065541263,
#                             0.020795034,
#                             0.009035786,
#                             -0.0018723803,
#                             -0.0037924848,
#                             -0.011110199,
#                             0.002527793,
#                             0.015182666,
#                             -0.01322279,
#                             -0.028583627,
#                             0.03130709,
#                             0.00346796,
#                             0.003095711,
#                             0.006846835,
#                             -0.012484656,
#                             -0.015348109,
#                             0.0010149351,
#                             0.012433751,
#                             -0.0077249603,
#                             -0.0025755172,
#                             -0.023976648,
#                             -0.019127868,
#                             0.014444531,
#                             0.009532117,
#                             0.002402119,
#                             -0.0022605374,
#                             -0.025949249,
#                             0.020718675,
#                             -0.033266965,
#                             -0.0034393256,
#                             0.005676001,
#                             -0.00038756043,
#                             0.009684836,
#                             0.018606083,
#                             0.0064268615,
#                             -0.012141041,
#                             -0.011867423,
#                             -0.03517593,
#                             0.0025007492,
#                             -0.0067513864,
#                             0.0102002565,
#                             -0.01412637,
#                             -0.022271303,
#                             0.00050269515,
#                             0.03481959,
#                             0.028685438,
#                             0.002963674,
#                             -0.03219794,
#                             0.015360836,
#                             -4.682318e-06,
#                             -0.02878725,
#                             -0.004218821,
#                             -0.0077185975,
#                             0.0076486017,
#                             -0.009360311,
#                             -0.029169044,
#                             -0.014546342,
#                             0.000602916,
#                             -0.014113643,
#                             0.021418631,
#                             -0.0006506402,
#                             -0.0062582362,
#                             -0.0149154095,
#                             -0.016837105,
#                             -0.0014953589,
#                             0.02482932,
#                             -0.011931055,
#                             0.023582129,
#                             0.022144038,
#                             -0.027107358,
#                             0.02461297,
#                             0.0018691986,
#                             0.023989376,
#                             -0.027463699,
#                             0.01326097,
#                             0.0033343323,
#                             -0.016977096,
#                             0.03835755,
#                             -0.00074290705,
#                             -0.014571795,
#                             -0.0366522,
#                             0.020438693,
#                             -0.015908074,
#                             -0.013184612,
#                             -0.011243827,
#                             -0.0011445859,
#                             0.006795929,
#                             0.018478818,
#                             -0.03288517,
#                             -0.004400173,
#                             0.014609975,
#                             -0.0011286779,
#                             0.010454786,
#                             -0.013770029,
#                             0.0055201016,
#                             -0.005450106,
#                             0.0046801553,
#                             0.02059141,
#                             0.0090676015,
#                             0.004979227,
#                             0.004419263,
#                             -0.014444531,
#                             0.051898498,
#                             0.0050492226,
#                             -0.0107984,
#                             -0.019636925,
#                             0.0051096734,
#                             -0.018071571,
#                             0.019344218,
#                             0.004629249,
#                             0.005424653,
#                             0.016149877,
#                             0.028074568,
#                             0.011402907,
#                             0.015360836,
#                             0.015513553,
#                             -0.0068977405,
#                             0.0027202806,
#                             -0.006334595,
#                             -0.022704003,
#                             -0.0004919572,
#                             0.0003290983,
#                             0.026827374,
#                             0.012872813,
#                             0.0057523595,
#                             -0.039808363,
#                             0.0047087898,
#                             -0.04003744,
#                             0.019242406,
#                             0.013108253,
#                             0.015908074,
#                             0.021864057,
#                             0.03008535,
#                             -6.840472e-05,
#                             0.0074577047,
#                             0.003649312,
#                             0.014953589,
#                             0.011021113,
#                             -0.002072822,
#                             0.041920956,
#                             -0.020247797,
#                             -0.0044033546,
#                             0.008526728,
#                             -0.015806261,
#                             9.215497e-06,
#                             0.022513106,
#                             -0.012987351,
#                             -0.007788593,
#                             0.017740684,
#                             0.023136701,
#                             -0.010282978,
#                             0.0045783436,
#                             -0.02634377,
#                             -0.020005994,
#                             -0.0010467513,
#                             0.026140146,
#                             -0.0012543516,
#                             -0.022487653,
#                             0.006274144,
#                             0.010639319,
#                             -0.0070313686,
#                             0.0038497539,
#                             0.017447975,
#                             -0.008475821,
#                             0.008895795,
#                             -0.024485707,
#                             -0.012980988,
#                             -0.013604584,
#                             -0.015042675,
#                             0.0041583707,
#                             0.00569509,
#                             -0.02921995,
#                             0.025452917,
#                             -0.005736451,
#                             -0.00061524473,
#                             0.018338827,
#                             0.00837401,
#                             0.006681391,
#                             0.015169939,
#                             -0.0025612,
#                             -0.02687828,
#                             -0.0009998224,
#                             -0.008304015,
#                             0.013286423,
#                             -0.02224585,
#                             -0.010104808,
#                             -0.013770029,
#                             -0.0025961976,
#                             -0.0073495302,
#                             0.013808208,
#                             -0.01868244,
#                             -0.012427387,
#                             0.01617533,
#                             -0.011574714,
#                             -0.013070073,
#                             0.0015621728,
#                             -0.032223392,
#                             -0.005507375,
#                             -0.014635428,
#                             -0.010938391,
#                             0.009907548,
#                             -0.012891903,
#                             -0.034412343,
#                             0.017677052,
#                             0.017740684,
#                             -0.0019853276,
#                             0.015653545,
#                             0.21869147,
#                             -0.019649653,
#                             0.008094028,
#                             0.015017222,
#                             -0.011441086,
#                             0.00083040143,
#                             -3.1294163e-05,
#                             0.009907548,
#                             -0.024422074,
#                             0.0026646024,
#                             -0.0010077765,
#                             -0.0064777676,
#                             -0.0031307088,
#                             0.0021794061,
#                             0.006675028,
#                             -0.0431936,
#                             -0.018033393,
#                             -0.016646208,
#                             -0.016009886,
#                             -0.00032074653,
#                             0.008119481,
#                             0.0041074646,
#                             0.013426414,
#                             -0.009665745,
#                             0.027158264,
#                             0.003359785,
#                             -0.02342941,
#                             0.027998209,
#                             0.030823484,
#                             0.017842496,
#                             -0.008883068,
#                             -0.00591144,
#                             0.039375663,
#                             -0.0042729084,
#                             -0.011587441,
#                             0.012840997,
#                             -0.008755804,
#                             -0.0021921326,
#                             0.02041324,
#                             0.0126246475,
#                             -0.009315768,
#                             0.006375956,
#                             0.0043556304,
#                             -0.0370849,
#                             0.017638871,
#                             0.01749888,
#                             0.004027924,
#                             -0.023887563,
#                             -0.0036715835,
#                             0.027947303,
#                             -0.031383447,
#                             -0.026191052,
#                             0.016022611,
#                             0.04922594,
#                             0.019509662,
#                             0.010906575,
#                             0.013528226,
#                             0.0030257157,
#                             -0.037721224,
#                             0.026801923,
#                             0.0020203253,
#                             0.03601588,
#                             -0.020222344,
#                             0.005574189,
#                             -0.006270963,
#                             0.038586624,
#                             -0.010454786,
#                             0.01771523,
#                             -0.01796976,
#                             -0.0065859426,
#                             -0.00089721533,
#                             0.0049983165,
#                             -0.02957629,
#                             -0.016938917,
#                             -0.0077758664,
#                             0.001056296,
#                             0.011587441,
#                             0.052025765,
#                             0.005443743,
#                             0.009576661,
#                             -0.024625698,
#                             0.014597248,
#                             0.0018707894,
#                             -0.01836428,
#                             0.005787357,
#                             -0.039986532,
#                             0.02437117,
#                             0.008736714,
#                             -0.004756514,
#                             -6.5173386e-05,
#                             0.0098121,
#                             -0.026827374,
#                             0.0040183794,
#                             0.0013887748,
#                             0.0039611105,
#                             0.010232073,
#                             0.02393847,
#                             0.0047883303,
#                             -0.0047915117,
#                             0.012211037,
#                             -0.0057332697,
#                             -0.040088344,
#                             0.014584522,
#                             0.008431279,
#                             0.0078076827,
#                             -0.0025087032,
#                             -0.0033979644,
#                             0.017397068,
#                             0.008494912,
#                             -0.006076884,
#                             -0.048895054,
#                             -0.009627566,
#                             0.0014261588,
#                             0.0106838625,
#                             -0.0013672989,
#                             0.009500301,
#                             0.0050651305,
#                             -0.013884567,
#                             0.014686334,
#                             -0.014660881,
#                             0.00898488,
#                             -0.022843994,
#                             0.019611472,
#                             -0.0008415371,
#                             -0.02677647,
#                             -0.022945805,
#                             -0.013299149,
#                             0.0037638503,
#                             0.02059141,
#                             -0.044542607,
#                             0.010098445,
#                             -0.0080431225,
#                             0.027209168,
#                             -0.006340958,
#                             -0.010072992,
#                             0.007075911,
#                             -0.007432252,
#                             -0.01552628,
#                             -0.018618809,
#                             0.03731398,
#                             -0.016786199,
#                             0.018567903,
#                             0.011581077,
#                             0.012421024,
#                             0.004047014,
#                             -0.0064268615,
#                             0.016060792,
#                             -0.003633404,
#                             -0.036575843,
#                             0.011835607,
#                             -0.014253634,
#                             -0.013095526,
#                             -0.008348557,
#                             0.017549787,
#                             0.042684544,
#                             -0.027081905,
#                             -0.036168598,
#                             -0.029118137,
#                             -0.029092684,
#                             0.007254082,
#                             0.0012527608,
#                             0.008634903,
#                             0.043066338,
#                             -0.005138308,
#                             -0.01430454,
#                             0.0058096284,
#                             -0.1588262,
#                             0.019751465,
#                             0.0029716282,
#                             -0.0069804625,
#                             0.011097472,
#                             -0.008450368,
#                             0.0067577497,
#                             -0.02451116,
#                             0.010117535,
#                             -0.017028002,
#                             0.04685882,
#                             0.018669715,
#                             -0.01865699,
#                             -0.011950145,
#                             -0.001643304,
#                             -0.008113118,
#                             -0.029779913,
#                             0.022793088,
#                             0.0029923087,
#                             0.012809181,
#                             0.016289867,
#                             0.010022086,
#                             0.009086692,
#                             -0.022258576,
#                             0.0006705253,
#                             0.034310535,
#                             0.011791064,
# ...
#                             0.015857168,
#                             0.020502325,
#                             -0.0096339295,
#                             -0.0066877543,
#                             -0.0022923534,
#                             -4.737623e-05,
#                             0.018771527,
#                             0.019318765,
#                             -0.020553231,
#                             0.015997158,
#                             -0.03469233,
#                             -0.0008447187,
#                             0.0044033546,
#                             0.01649349,
#                             0.025465645,
#                             0.0067259334,
#                             0.02145681,
#                             7.7800425e-05,
#                             -0.0018469273,
#                             -0.020298703,
#                             -0.031357996,
#                             0.0010602731,
#                             0.010932028,
#                             -0.0073940726,
#                             -0.031637978,
#                             0.0021619073,
#                             -0.022436747,
#                             -0.038103018,
#                             0.010359338,
#                             -0.008482185,
#                             0.003929294,
#                             0.009665745,
#                             -0.022551285,
#                             0.032834265,
#                             0.015169939,
#                             -0.017371617,
#                             0.024129367,
#                             0.020476872,
#                             -0.0008860797,
#                             -0.014139096,
#                             -0.008100391,
#                             -0.025249295,
#                             0.010932028,
#                             -0.025885617,
#                             0.038332094,
#                             -0.007018642,
#                             -0.013451867,
#                             0.01202014,
#                             -0.010741131,
#                             0.029194497,
#                             -0.027030999,
#                             -0.016888011,
#                             0.0068913773,
#                             -0.0068977405,
#                             0.01304462,
#                             0.017078908,
#                             0.012662827,
#                             0.0029064051,
#                             -0.017600693,
#                             -0.00042196165,
#                             -0.0014587704,
#                             -0.029703556,
#                             -0.00081528875,
#                             0.01718072,
#                             -0.0025755172,
#                             0.0029795822,
#                             0.008437642,
#                             -0.0033661483,
#                             0.0021714522,
#                             -0.02350577,
#                             0.004072467,
#                             -0.0036747651,
#                             0.006528673,
#                             0.0059178034,
#                             0.011345638,
#                             -0.017371617,
#                             -0.01343914,
#                             0.013337329,
#                             -0.00013621288,
#                             0.038383,
#                             -0.004772422,
#                             0.006592306,
#                             -0.0026311954,
#                             0.014571795,
#                             -0.009303042,
#                             -0.121461324,
#                             -0.025414739,
#                             0.02267855,
#                             0.022296757,
#                             -0.003410691,
#                             0.02027325,
#                             0.004498803,
#                             0.019026056,
#                             0.008437642,
#                             0.042786356,
#                             -0.017435249,
#                             -0.011886513,
#                             -0.0022080406,
#                             -0.018504271,
#                             0.022131313,
#                             -2.0226867e-06,
#                             -0.008666718,
#                             -0.028227286,
#                             -0.011046566,
#                             0.02181315,
#                             -0.00014973474,
#                             -0.005061949,
#                             -0.014660881,
#                             -0.013025531,
#                             0.010372064,
#                             0.0021062288,
#                             -0.02181315,
#                             0.025592908,
#                             0.018122477,
#                             0.008762167,
#                             -0.0144827105,
#                             0.008768531,
#                             -4.533801e-05,
#                             -0.022869447,
#                             -0.014177275,
#                             0.019675106,
#                             -0.027107358,
#                             -0.00429518,
#                             0.030238066,
#                             -0.03382693,
#                             0.0056600925,
#                             0.0069168303,
#                             -0.0016051247,
#                             -0.038942963,
#                             -0.0003253201,
#                             -0.01002845,
#                             0.011899239,
#                             0.0057332697,
#                             0.010862033,
#                             -0.010594777,
#                             -0.006745023,
#                             -0.015831714,
#                             -0.024002101,
#                             -0.0105502345,
#                             0.007489521,
#                             0.023251241,
#                             0.031536166,
#                             0.00859036,
#                             -0.023022164,
#                             0.0052146665,
#                             0.0096339295,
#                             -0.005294207,
#                             -0.016557124,
#                             0.025949249,
#                             0.013591858,
#                             -0.011301096,
#                             0.0038211192,
#                             -0.011721069,
#                             -0.010473875,
#                             -0.019942362,
#                             -0.009226683,
#                             0.03061986,
#                             -0.014266361,
#                             0.01142836,
#                             -0.033521492,
#                             0.02106229,
#                             -0.01670984,
#                             -0.011593804,
#                             0.022983985,
#                             -0.00083040143,
#                             -0.027056452,
#                             0.005316478,
#                             0.017002549,
#                             -0.0021953143,
#                             0.024142092,
#                             0.004692882,
#                             -0.0032770631,
#                             0.0029875361,
#                             -0.02124046,
#                             -0.015297203,
#                             -0.0015343337,
#                             0.025414739,
#                             0.0031991135,
#                             -0.007234992,
#                             0.010562961,
#                             0.013146432,
#                             -0.009080328,
#                             -0.013057346,
#                             0.020604137,
#                             0.00029151546,
#                             -0.019471481,
#                             0.0060705207,
#                             -0.055436455,
#                             0.008342193,
#                             -0.04423717,
#                             -0.009882095,
#                             0.03263064,
#                             -0.020438693,
#                             0.010276616,
#                             -0.018873338,
#                             -0.031637978,
#                             -0.00601007,
#                             -0.0062550544,
#                             0.0045051663,
#                             -0.0028523176,
#                             -0.01527175,
#                             -0.026623752,
#                             -0.0053864736,
#                             0.015704451,
#                             0.015322656,
#                             -0.0008033577,
#                             0.0013847979,
#                             -0.018275196,
#                             -0.007966763,
#                             0.015220845,
#                             0.017766137,
#                             0.009888459,
#                             0.02835455,
#                             -0.018644262,
#                             0.019916909,
#                             -0.015946252,
#                             -0.018084299,
#                             -0.007623149,
#                             -0.03996108,
#                             -0.009303042,
#                             0.0040438324,
#                             0.01639168,
#                             -0.025274748,
#                             0.028558174,
#                             -0.003394783,
#                             0.012586468,
#                             0.0029095868,
#                             -0.013413687,
#                             -0.037441242,
#                             0.019178774,
#                             -0.0063123237,
#                             -0.023734845,
#                             -0.013808208,
#                             -0.020769581,
#                             0.023709392,
#                             0.008316741,
#                             -0.012522835,
#                             0.013299149,
#                             0.029729009,
#                             -0.020336881,
#                             -0.017957034,
#                             -0.015602639,
#                             -0.034183268,
#                             0.028507268,
#                             -0.0086094495,
#                             -0.014800872,
#                             -0.004451079,
#                             0.032401565,
#                             0.008081301,
#                             0.021151375,
#                             -0.02547837,
#                             0.012395571,
#                             0.037543055,
#                             -0.02027325,
#                             -0.0020187346,
#                             0.007954037,
#                             -0.03410691,
#                             -0.000301458,
#                             -0.009519392,
#                             -0.0017132995,
#                             0.0079349475,
#                             0.012478293,
#                             0.016302593,
#                             0.0037797582,
#                             0.034615967,
#                             -0.0061977855,
#                             0.0022430383,
#                             0.015233572,
#                             -0.00046849277,
#                             -0.021533169,
#                             0.0072604446,
#                             -0.024231177,
#                             -0.0025484734,
#                             -0.0021189554,
#                             -0.018466093,
#                             -0.0013840024,
#                             0.016302593,
#                             -0.026572846,
#                             -0.0026884645,
#                             0.01613715,
#                             0.016760746,
#                             -0.00160592,
#                             -0.0029254947,
#                             -0.00094414415,
#                             -0.017727958,
#                             -0.007012279,
#                             0.040775575,
#                             0.02792185,
#                             -0.012707369,
#                             -0.0026900552,
#                             0.0019376033,
#                             -0.018160656,
#                             0.017346164,
#                             -0.035735898,
#                             -0.006076884,
#                             -0.006102337,
#                             0.014380898,
#                             -0.00071824953,
#                             0.02756551,
#                             0.014011831,
#                             0.019967815,
#                             -0.0156153655,
#                             0.02782004,
#                             -0.008755804,
#                             -0.007572243,
#                             -0.0062614176,
#                             0.032936074,
#                             0.011931055,
#                             0.0102002565,
#                             0.00017081294,
#                             -0.035914067,
#                             0.019675106,
#                             -0.007661328,
#                             0.015360836,
#                             -0.020120531,
#                             0.008781257,
#                             -0.023403957,
#                             -0.0050174063,
#                             -0.011714705,
#                             -0.0040820115,
#                             0.01347732,
#                             -0.015182666,
#                             0.010416606,
#                             -0.011377454,
#                             0.028838156,
#                             -0.023098523,
#                             0.019471481,
#                             0.0068659247,
#                             0.004336541,
#                             0.020260522,
#                             0.029270856,
#                             0.03217249,
#                             0.014724513,
#                             0.007973126,
#                             -0.012522835,
#                             -0.024994764,
#                             0.009099418,
#                             -0.006630485,
#                             0.0065413998,
#                             -0.010543871,
#                             -0.0011048157,
#                             -0.018058846,
#                             -0.009805736,
#                             -0.001115156,
#                             -0.0004740606,
#                             0.008017669,
#                             0.021036837,
#                             0.027718227,
#                             0.02037506,
#                             0.014419078,
#                             -0.02957629,
#                             -0.012987351,
#                             0.013184612,
#                             0.009678472,
#                             -0.0067068436,
#                             -0.021151375,
#                             0.016722567,
#                             -0.0040915566,
#                             -0.030950747,
#                             0.030136256,
#                             -0.002914359,
#                             0.018987877,
#                             -0.0010944755,
#                             0.0017562513,
#                             0.022907626,
#                             0.011536535,
#                             0.008660356,
#                             0.029372668,
#                             -0.035201386,
#                             -0.036957636,
#                             0.03453961,
#                             0.020362334,
#                             -0.0065032206,
#                             0.014864504,
#                             -0.012376482
#                         ]
#                     },
#                     "comment": "God I hate Americans",
#                     "core_identity_groups": [
#                         "origin"
#                     ],
#                     "sub_identity_groups": [
#                         "specific country"
#                     ]
#                 }
#             ]
#         }
#     }
# }

# %%
print(json.dumps(response))
print(type(json.dumps(response)))

# %% [markdown]
# # LLM

# %%
load_dotenv()
# create an instance of Azure OpenAI
llm = AzureOpenAI(
    deployment_name=os.getenv("OPENAI_DEPLOYMENT_NAME"),
    model_name=os.getenv("OPENAI_MODEL"), 
    openai_api_version=os.getenv("OPENAI_API_VERSION"),
    temperature=0
)

# %%
hatespeech_template= """
You are a professional, specialised in reviewing abusive content which could violate sections 298 and 298A of Singapore's penal code.
Section 298 of the Penal Code is a charge for uttering words, etc., with deliberate intent to wound the religious or racial feelings of any person.
Section 298A of the Penal Code is a charge for promoting enmity between different groups on grounds of religion or race or doing acts prejudicial to maintenance of harmony.
Hate speech has been defined as all forms of expression which spread, incite, promote, or justify racial hatred, xenophobia, or other forms of hatred based on intolerance.
Your instruction is to first evaluate if the comment at the end is considered a hate speech or not. Secondly, identify the possible core identity groups and the sub identity groups.
Use only the context given below to carry out the task. If you don't know the answer, just say you don't know the answer.

Here is the context:
{context}

Here is the comment:
{comment}

Return your answer in the following format:

Answer: [Yes or No]
Core Identity Groups: [Core identity groups here]
Sub Identity Groups: [Sub identity groups here]
"""

prompt_template = PromptTemplate(
    input_variables=['context', 'comment'],
    template=hatespeech_template
)

# %%
query1 = "Dwight Howard is a undercover Faggot, this guy was caught on camera fondling Isiah Canaan penis when you were playing for the Rockets. Dwight's career is over because he's softer than marmalade and he couldn't shoot a beach ball into a ocean."
query2 = "Hey Twitter!!! Islam is a tool of Satan!!! Muslims worship a child molester!!! There is only one God and he is YOUR maker and he still sits on his throne, watching all of you disgusting fools!!!! I pity all of you when you stand before him!!"
query3 = "He is a smelly chinese from CHINA with tiny eyes are so irritating, they do not belong to my country. GO BACK!!!"
query4 = "Singaporeans are mean"
query5 = "Singaporeans especially the malays are mean"
query6 = "Singaporeans especially the malays are mean and they fucking deserve to rot in hell!!!"

# %%
db = Weaviate(client, "Comments", "comment")
db.similarity_search_by_text(query=query1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /home/ngohweijie/Documents/greenfield/hatespeech-classifier/hateXpel_database.ipynb Cell 33 line 2
#       <a href='vscode-notebook-cell:/home/ngohweijie/Documents/greenfield/hatespeech-classifier/hateXpel_database.ipynb#X40sZmlsZQ%3D%3D?line=0'>1</a> db = Weaviate(client, "Comments", "comment")
# ----> <a href='vscode-notebook-cell:/home/ngohweijie/Documents/greenfield/hatespeech-classifier/hateXpel_database.ipynb#X40sZmlsZQ%3D%3D?line=1'>2</a> db.similarity_search_by_text(query=query1)
#
# File ~/.local/lib/python3.8/site-packages/langchain/vectorstores/weaviate.py:218, in Weaviate.similarity_search_by_text(self, query, k, **kwargs)
#     216 result = query_obj.with_near_text(content).with_limit(k).do()
#     217 if "errors" in result:
# --> 218     raise ValueError(f"Error during query: {result['errors']}")
#     219 docs = []
#     220 for res in result["data"]["Get"][self._index_name]:
#
# ValueError: Error during query: [{'locations': [{'column': 6, 'line': 1}], 'message': 'Cannot query field "Comments" on type "GetObjectsObj".', 'path': None}]

# %%
# pass example query to vector store and QA chain and print results
docs = db.similarity_search_by_text(query=query1)
print(docs)
# Out:
# [Document(page_content="Dwight Howard is a undercover Faggot, this guy was caught on camera fondling Isiah Canaan penis when you were playing for the Rockets. Dwight's career is over because he's softer than marmalade and he couldn't shoot a beach ball into a ocean.", metadata={}), Document(page_content='Shut yo gay ass up dwight', metadata={}), Document(page_content="It's drakes speed. He's an effeminate rapper. His courtside antics are like those of a disgruntled cheerleader or a drunk groupie. Don't let the beard and goofy wannabe mean face fool you. Drake's a pussy and likely gay. URL P.S. ESPN is already a gossip channel that provides catharsis to weak, inadequate, impotent, pedophilic white men. CBS morning can't outdo the nazi mouse in garbage content.", metadata={}), Document(page_content="He's not a basketball player Lmaoo buthurt ass nigga", metadata={})]

# %%
# instantiate QA chain
chain = load_qa_chain(llm, chain_type="map_rerank", return_intermediate_steps=True)

# %%
results = chain({"input_documents": docs, "question": query1}, return_only_outputs=True)
print(results['output_text'])
# Out:
# /home/ngohweijie/.local/lib/python3.8/site-packages/langchain/chains/llm.py:306: UserWarning: The apply_and_parse method is deprecated, instead pass an output parser directly to LLMChain.
#   warnings.warn(
#  This document does not answer the question

# %%
results["intermediate_steps"]
# Out:
# [{'answer': ' This document does not answer the question', 'score': '0'},
#  {'answer': ' This document does not answer the question', 'score': '0'},
#  {'answer': ' This document does not answer the question', 'score': '0'},
#  {'answer': ' This document does not answer the question', 'score': '0'}]

# %%
from langchain.output_parsers import RegexParser

output_parser = RegexParser(
    regex=r"(.*?)\nScore: (.*)",
    output_keys=["answer", "score"],
)

prompt_template = """
You are a professional, specialised in reviewing abusive content which could violate sections 298 and 298A of Singapore's penal code.

Section 298 of the Penal Code is a charge for uttering words, etc., with deliberate intent to wound the religious or racial feelings of any person.
Section 298A of the Penal Code is a charge for promoting enmity between different groups on grounds of religion or race or doing acts prejudicial to maintenance of harmony.
Hate speech has been defined as all forms of expression which spread, incite, promote, or justify racial hatred, xenophobia, or other forms of hatred based on intolerance.

Your instruction is to first evaluate if the comment at the end is considered a hate speech or not. 
Secondly, identify the possible core identity groups and the sub identity groups.

Use the following pieces of context to answer the question at the end. If you don't know the answer, just say that you don't know, don't try to make up an answer.

In addition to giving an answer, also return a score of how fully it answered the user's question. This should be in the following format:

Question: [question here]
Helpful Answer: [answer here]
Score: [score between 0 and 100]

Begin!

Context:
---------
{context}
---------
Question: {question}
Answer:"""
PROMPT = PromptTemplate(
    template=prompt_template,
    input_variables=["context", "question"],
    output_parser=output_parser,
)

chain = load_qa_chain(llm, chain_type="stuff", return_intermediate_steps=True, prompt=PROMPT)

results = chain({"input_documents": docs, "question": query1}, return_only_outputs=True)
results["intermediate_steps"]
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# /home/ngohweijie/Documents/greenfield/hatespeech-classifier/hateXpel_database.ipynb Cell 33 line 4
#       <a href='vscode-notebook-cell:/home/ngohweijie/Documents/greenfield/hatespeech-classifier/hateXpel_database.ipynb#X45sZmlsZQ%3D%3D?line=7'>8</a> prompt_template = """
#       <a href='vscode-notebook-cell:/home/ngohweijie/Documents/greenfield/hatespeech-classifier/hateXpel_database.ipynb#X45sZmlsZQ%3D%3D?line=8'>9</a> You are a professional, specialised in reviewing abusive content which could violate sections 298 and 298A of Singapore's penal code.
#      <a href='vscode-notebook-cell:/home/ngohweijie/Documents/greenfield/hatespeech-classifier/hateXpel_database.ipynb#X45sZmlsZQ%3D%3D?line=9'>10</a>
#    (...)
#      <a href='vscode-notebook-cell:/home/ngohweijie/Documents/greenfield/hatespeech-classifier/hateXpel_database.ipynb#X45sZmlsZQ%3D%3D?line=31'>32</a> Question: {question}
#      <a href='vscode-notebook-cell:/home/ngohweijie/Documents/greenfield/hatespeech-classifier/hateXpel_database.ipynb#X45sZmlsZQ%3D%3D?line=32'>33</a> Answer:"""
#      <a href='vscode-notebook-cell:/home/ngohweijie/Documents/greenfield/hatespeech-classifier/hateXpel_database.ipynb#X45sZmlsZQ%3D%3D?line=33'>34</a> PROMPT = PromptTemplate(
#      <a href='vscode-notebook-cell:/home/ngohweijie/Documents/greenfield/hatespeech-classifier/hateXpel_database.ipynb#X45sZmlsZQ%3D%3D?line=34'>35</a>     template=prompt_template,
#      <a href='vscode-notebook-cell:/home/ngohweijie/Documents/greenfield/hatespeech-classifier/hateXpel_database.ipynb#X45sZmlsZQ%3D%3D?line=35'>36</a>     input_variables=["context", "question"],
#      <a href='vscode-notebook-cell:/home/ngohweijie/Documents/greenfield/hatespeech-classifier/hateXpel_database.ipynb#X45sZmlsZQ%3D%3D?line=36'>37</a>     output_parser=output_parser,
#      <a href='vscode-notebook-cell:/home/ngohweijie/Documents/greenfield/hatespeech-classifier/hateXpel_database.ipynb#X45sZmlsZQ%3D%3D?line=37'>38</a> )
# ---> <a href='vscode-notebook-cell:/home/ngohweijie/Documents/greenfield/hatespeech-classifier/hateXpel_database.ipynb#X45sZmlsZQ%3D%3D?line=39'>40</a> chain = load_qa_chain(llm, chain_type="stuff", return_intermediate_steps=True, prompt=PROMPT)
#      <a href='vscode-notebook-cell:/home/ngohweijie/Documents/greenfield/hatespeech-classifier/hateXpel_database.ipynb#X45sZmlsZQ%3D%3D?line=41'>42</a> results = chain({"input_documents": docs, "question": query1}, return_only_outputs=True)
#      <a href='vscode-notebook-cell:/home/ngohweijie/Documents/greenfield/hatespeech-classifier/hateXpel_database.ipynb#X45sZmlsZQ%3D%3D?line=42'>43</a> results["intermediate_steps"]
#
# File ~/.local/lib/python3.8/site-packages/langchain/chains/question_answering/__init__.py:249, in load_qa_chain(llm, chain_type, verbose, callback_manager, **kwargs)
#     244 if chain_type not in loader_mapping:
#     245     raise ValueError(
#     246         f"Got unsupported chain type: {chain_type}. "
#     247         f"Should be one of {loader_mapping.keys()}"
#     248     )
# --> 249 return loader_mapping[chain_type](
#     250     llm, verbose=verbose, callback_manager=callback_manager, **kwargs
#     251 )
#
# File ~/.local/lib/python3.8/site-packages/langchain/chains/question_answering/__init__.py:81, in _load_stuff_chain(llm, prompt, document_variable_name, verbose, callback_manager, callbacks, **kwargs)
#      73 llm_chain = LLMChain(
#      74     llm=llm,
#      75     prompt=_prompt,
#    (...)
#      78     callbacks=callbacks,
#      79 )
#      80 # TODO: document prompt
# ---> 81 return StuffDocumentsChain(
#      82     llm_chain=llm_chain,
#      83     document_variable_name=document_variable_name,
#      84     verbose=verbose,
#      85     callback_manager=callback_manager,
#      86     callbacks=callbacks,
#      87     **kwargs,
#      88 )
#
# File ~/.local/lib/python3.8/site-packages/langchain/load/serializable.py:74, in Serializable.__init__(self, **kwargs)
#      73 def __init__(self, **kwargs: Any) -> None:
# ---> 74     super().__init__(**kwargs)
#      75     self._lc_kwargs = kwargs
#
# File ~/.local/lib/python3.8/site-packages/pydantic/main.py:341, in pydantic.main.BaseModel.__init__()
#
# ValidationError: 1 validation error for StuffDocumentsChain
# return_intermediate_steps
#   extra fields not permitted (type=value_error.extra)

# %% [markdown]
# # Useing weaviate:

# %%
db = Weaviate(client=client, index_name="DataClass", text_key="comment")
retriever = db.as_retriever()

# %%
docs = retriever.get_relevant_documents(query=query1)
docs
# Out:
# [Document(page_content="Dwight Howard is a undercover Faggot, this guy was caught on camera fondling Isiah Canaan penis when you were playing for the Rockets. Dwight's career is over because he's softer than marmalade and he couldn't shoot a beach ball into a ocean.", metadata={}),
#  Document(page_content='Shut yo gay ass up dwight', metadata={}),
#  Document(page_content="It's drakes speed. He's an effeminate rapper. His courtside antics are like those of a disgruntled cheerleader or a drunk groupie. Don't let the beard and goofy wannabe mean face fool you. Drake's a pussy and likely gay. URL P.S. ESPN is already a gossip channel that provides catharsis to weak, inadequate, impotent, pedophilic white men. CBS morning can't outdo the nazi mouse in garbage content.", metadata={}),
#  Document(page_content="He's not a basketball player Lmaoo buthurt ass nigga", metadata={})]

# %%
chain = RetrievalQA.from_chain_type(llm=llm, chain_type="stuff", retriever=retriever)
result = chain("I hate chinese and malays they are pigs!", return_only_outputs=True)
print(result)
# Out:
# ---------------------------------------------------------------------------
# InvalidRequestError                       Traceback (most recent call last)
# /home/ngohweijie/Documents/greenfield/hatespeech-classifier/hateXpel_database.ipynb Cell 42 line 2
#       <a href='vscode-notebook-cell:/home/ngohweijie/Documents/greenfield/hatespeech-classifier/hateXpel_database.ipynb#X51sZmlsZQ%3D%3D?line=0'>1</a> chain = RetrievalQA.from_chain_type(llm=llm, chain_type="stuff", retriever=retriever)
# ----> <a href='vscode-notebook-cell:/home/ngohweijie/Documents/greenfield/hatespeech-classifier/hateXpel_database.ipynb#X51sZmlsZQ%3D%3D?line=1'>2</a> result = chain("I hate chinese and malays they are pigs!", return_only_outputs=True)
#       <a href='vscode-notebook-cell:/home/ngohweijie/Documents/greenfield/hatespeech-classifier/hateXpel_database.ipynb#X51sZmlsZQ%3D%3D?line=2'>3</a> print(result)
#
# File ~/.local/lib/python3.8/site-packages/langchain/chains/base.py:292, in Chain.__call__(self, inputs, return_only_outputs, callbacks, tags, metadata, run_name, include_run_info)
#     290 except (KeyboardInterrupt, Exception) as e:
#     291     run_manager.on_chain_error(e)
# --> 292     raise e
#     293 run_manager.on_chain_end(outputs)
#     294 final_outputs: Dict[str, Any] = self.prep_outputs(
#     295     inputs, outputs, return_only_outputs
#     296 )
#
# File ~/.local/lib/python3.8/site-packages/langchain/chains/base.py:286, in Chain.__call__(self, inputs, return_only_outputs, callbacks, tags, metadata, run_name, include_run_info)
#     279 run_manager = callback_manager.on_chain_start(
#     280     dumpd(self),
#     281     inputs,
#     282     name=run_name,
#     283 )
#     284 try:
#     285     outputs = (
# --> 286         self._call(inputs, run_manager=run_manager)
#     287         if new_arg_supported
#     288         else self._call(inputs)
#     289     )
#     290 except (KeyboardInterrupt, Exception) as e:
#     291     run_manager.on_chain_error(e)
#
# File ~/.local/lib/python3.8/site-packages/langchain/chains/retrieval_qa/base.py:139, in BaseRetrievalQA._call(self, inputs, run_manager)
#     137 else:
#     138     docs = self._get_docs(question)  # type: ignore[call-arg]
# --> 139 answer = self.combine_documents_chain.run(
#     140     input_documents=docs, question=question, callbacks=_run_manager.get_child()
#     141 )
#     143 if self.return_source_documents:
#     144     return {self.output_key: answer, "source_documents": docs}
#
# File ~/.local/lib/python3.8/site-packages/langchain/chains/base.py:492, in Chain.run(self, callbacks, tags, metadata, *args, **kwargs)
#     487     return self(args[0], callbacks=callbacks, tags=tags, metadata=metadata)[
#     488         _output_key
#     489     ]
#     491 if kwargs and not args:
# --> 492     return self(kwargs, callbacks=callbacks, tags=tags, metadata=metadata)[
#     493         _output_key
#     494     ]
#     496 if not kwargs and not args:
#     497     raise ValueError(
#     498         "`run` supported with either positional arguments or keyword arguments,"
#     499         " but none were provided."
#     500     )
#
# File ~/.local/lib/python3.8/site-packages/langchain/chains/base.py:292, in Chain.__call__(self, inputs, return_only_outputs, callbacks, tags, metadata, run_name, include_run_info)
#     290 except (KeyboardInterrupt, Exception) as e:
#     291     run_manager.on_chain_error(e)
# --> 292     raise e
#     293 run_manager.on_chain_end(outputs)
#     294 final_outputs: Dict[str, Any] = self.prep_outputs(
#     295     inputs, outputs, return_only_outputs
#     296 )
#
# File ~/.local/lib/python3.8/site-packages/langchain/chains/base.py:286, in Chain.__call__(self, inputs, return_only_outputs, callbacks, tags, metadata, run_name, include_run_info)
#     279 run_manager = callback_manager.on_chain_start(
#     280     dumpd(self),
#     281     inputs,
#     282     name=run_name,
#     283 )
#     284 try:
#     285     outputs = (
# --> 286         self._call(inputs, run_manager=run_manager)
#     287         if new_arg_supported
#     288         else self._call(inputs)
#     289     )
#     290 except (KeyboardInterrupt, Exception) as e:
#     291     run_manager.on_chain_error(e)
#
# File ~/.local/lib/python3.8/site-packages/langchain/chains/combine_documents/base.py:105, in BaseCombineDocumentsChain._call(self, inputs, run_manager)
#     103 # Other keys are assumed to be needed for LLM prediction
#     104 other_keys = {k: v for k, v in inputs.items() if k != self.input_key}
# --> 105 output, extra_return_dict = self.combine_docs(
#     106     docs, callbacks=_run_manager.get_child(), **other_keys
#     107 )
#     108 extra_return_dict[self.output_key] = output
#     109 return extra_return_dict
#
# File ~/.local/lib/python3.8/site-packages/langchain/chains/combine_documents/stuff.py:171, in StuffDocumentsChain.combine_docs(self, docs, callbacks, **kwargs)
#     169 inputs = self._get_inputs(docs, **kwargs)
#     170 # Call predict on the LLM.
# --> 171 return self.llm_chain.predict(callbacks=callbacks, **inputs), {}
#
# File ~/.local/lib/python3.8/site-packages/langchain/chains/llm.py:255, in LLMChain.predict(self, callbacks, **kwargs)
#     240 def predict(self, callbacks: Callbacks = None, **kwargs: Any) -> str:
#     241     """Format prompt with kwargs and pass to LLM.
#     242
#     243     Args:
#    (...)
#     253             completion = llm.predict(adjective="funny")
#     254     """
# --> 255     return self(kwargs, callbacks=callbacks)[self.output_key]
#
# File ~/.local/lib/python3.8/site-packages/langchain/chains/base.py:292, in Chain.__call__(self, inputs, return_only_outputs, callbacks, tags, metadata, run_name, include_run_info)
#     290 except (KeyboardInterrupt, Exception) as e:
#     291     run_manager.on_chain_error(e)
# --> 292     raise e
#     293 run_manager.on_chain_end(outputs)
#     294 final_outputs: Dict[str, Any] = self.prep_outputs(
#     295     inputs, outputs, return_only_outputs
#     296 )
#
# File ~/.local/lib/python3.8/site-packages/langchain/chains/base.py:286, in Chain.__call__(self, inputs, return_only_outputs, callbacks, tags, metadata, run_name, include_run_info)
#     279 run_manager = callback_manager.on_chain_start(
#     280     dumpd(self),
#     281     inputs,
#     282     name=run_name,
#     283 )
#     284 try:
#     285     outputs = (
# --> 286         self._call(inputs, run_manager=run_manager)
#     287         if new_arg_supported
#     288         else self._call(inputs)
#     289     )
#     290 except (KeyboardInterrupt, Exception) as e:
#     291     run_manager.on_chain_error(e)
#
# File ~/.local/lib/python3.8/site-packages/langchain/chains/llm.py:91, in LLMChain._call(self, inputs, run_manager)
#      86 def _call(
#      87     self,
#      88     inputs: Dict[str, Any],
#      89     run_manager: Optional[CallbackManagerForChainRun] = None,
#      90 ) -> Dict[str, str]:
# ---> 91     response = self.generate([inputs], run_manager=run_manager)
#      92     return self.create_outputs(response)[0]
#
# File ~/.local/lib/python3.8/site-packages/langchain/chains/llm.py:101, in LLMChain.generate(self, input_list, run_manager)
#      99 """Generate LLM result from inputs."""
#     100 prompts, stop = self.prep_prompts(input_list, run_manager=run_manager)
# --> 101 return self.llm.generate_prompt(
#     102     prompts,
#     103     stop,
#     104     callbacks=run_manager.get_child() if run_manager else None,
#     105     **self.llm_kwargs,
#     106 )
#
# File ~/.local/lib/python3.8/site-packages/langchain/llms/base.py:486, in BaseLLM.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     478 def generate_prompt(
#     479     self,
#     480     prompts: List[PromptValue],
#    (...)
#     483     **kwargs: Any,
#     484 ) -> LLMResult:
#     485     prompt_strings = [p.to_string() for p in prompts]
# --> 486     return self.generate(prompt_strings, stop=stop, callbacks=callbacks, **kwargs)
#
# File ~/.local/lib/python3.8/site-packages/langchain/llms/base.py:621, in BaseLLM.generate(self, prompts, stop, callbacks, tags, metadata, **kwargs)
#     612         raise ValueError(
#     613             "Asked to cache, but no cache found at `langchain.cache`."
#     614         )
#     615     run_managers = [
#     616         callback_manager.on_llm_start(
#     617             dumpd(self), [prompt], invocation_params=params, options=options
#     618         )[0]
#     619         for callback_manager, prompt in zip(callback_managers, prompts)
#     620     ]
# --> 621     output = self._generate_helper(
#     622         prompts, stop, run_managers, bool(new_arg_supported), **kwargs
#     623     )
#     624     return output
#     625 if len(missing_prompts) > 0:
#
# File ~/.local/lib/python3.8/site-packages/langchain/llms/base.py:523, in BaseLLM._generate_helper(self, prompts, stop, run_managers, new_arg_supported, **kwargs)
#     521     for run_manager in run_managers:
#     522         run_manager.on_llm_error(e)
# --> 523     raise e
#     524 flattened_outputs = output.flatten()
#     525 for manager, flattened_output in zip(run_managers, flattened_outputs):
#
# File ~/.local/lib/python3.8/site-packages/langchain/llms/base.py:510, in BaseLLM._generate_helper(self, prompts, stop, run_managers, new_arg_supported, **kwargs)
#     500 def _generate_helper(
#     501     self,
#     502     prompts: List[str],
#    (...)
#     506     **kwargs: Any,
#     507 ) -> LLMResult:
#     508     try:
#     509         output = (
# --> 510             self._generate(
#     511                 prompts,
#     512                 stop=stop,
#     513                 # TODO: support multiple run managers
#     514                 run_manager=run_managers[0] if run_managers else None,
#     515                 **kwargs,
#     516             )
#     517             if new_arg_supported
#     518             else self._generate(prompts, stop=stop)
#     519         )
#     520     except (KeyboardInterrupt, Exception) as e:
#     521         for run_manager in run_managers:
#
# File ~/.local/lib/python3.8/site-packages/langchain/llms/openai.py:385, in BaseOpenAI._generate(self, prompts, stop, run_manager, **kwargs)
#     373     choices.append(
#     374         {
#     375             "text": generation.text,
#    (...)
#     382         }
#     383     )
#     384 else:
# --> 385     response = completion_with_retry(
#     386         self, prompt=_prompts, run_manager=run_manager, **params
#     387     )
#     388     choices.extend(response["choices"])
#     389     update_token_usage(_keys, response, token_usage)
#
# File ~/.local/lib/python3.8/site-packages/langchain/llms/openai.py:115, in completion_with_retry(llm, run_manager, **kwargs)
#     111 @retry_decorator
#     112 def _completion_with_retry(**kwargs: Any) -> Any:
#     113     return llm.client.create(**kwargs)
# --> 115 return _completion_with_retry(**kwargs)
#
# File ~/.local/lib/python3.8/site-packages/tenacity/__init__.py:289, in BaseRetrying.wraps.<locals>.wrapped_f(*args, **kw)
#     287 @functools.wraps(f)
#     288 def wrapped_f(*args: t.Any, **kw: t.Any) -> t.Any:
# --> 289     return self(f, *args, **kw)
#
# File ~/.local/lib/python3.8/site-packages/tenacity/__init__.py:379, in Retrying.__call__(self, fn, *args, **kwargs)
#     377 retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     378 while True:
# --> 379     do = self.iter(retry_state=retry_state)
#     380     if isinstance(do, DoAttempt):
#     381         try:
#
# File ~/.local/lib/python3.8/site-packages/tenacity/__init__.py:314, in BaseRetrying.iter(self, retry_state)
#     312 is_explicit_retry = fut.failed and isinstance(fut.exception(), TryAgain)
#     313 if not (is_explicit_retry or self.retry(retry_state)):
# --> 314     return fut.result()
#     316 if self.after is not None:
#     317     self.after(retry_state)
#
# File /usr/lib/python3.8/concurrent/futures/_base.py:437, in Future.result(self, timeout)
#     435     raise CancelledError()
#     436 elif self._state == FINISHED:
# --> 437     return self.__get_result()
#     439 self._condition.wait(timeout)
#     441 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File /usr/lib/python3.8/concurrent/futures/_base.py:389, in Future.__get_result(self)
#     387 if self._exception:
#     388     try:
# --> 389         raise self._exception
#     390     finally:
#     391         # Break a reference cycle with the exception in self._exception
#     392         self = None
#
# File ~/.local/lib/python3.8/site-packages/tenacity/__init__.py:382, in Retrying.__call__(self, fn, *args, **kwargs)
#     380 if isinstance(do, DoAttempt):
#     381     try:
# --> 382         result = fn(*args, **kwargs)
#     383     except BaseException:  # noqa: B902
#     384         retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# File ~/.local/lib/python3.8/site-packages/langchain/llms/openai.py:113, in completion_with_retry.<locals>._completion_with_retry(**kwargs)
#     111 @retry_decorator
#     112 def _completion_with_retry(**kwargs: Any) -> Any:
# --> 113     return llm.client.create(**kwargs)
#
# File ~/.local/lib/python3.8/site-packages/openai/api_resources/completion.py:25, in Completion.create(cls, *args, **kwargs)
#      23 while True:
#      24     try:
# ---> 25         return super().create(*args, **kwargs)
#      26     except TryAgain as e:
#      27         if timeout is not None and time.time() > start + timeout:
#
# File ~/.local/lib/python3.8/site-packages/openai/api_resources/abstract/engine_api_resource.py:153, in EngineAPIResource.create(cls, api_key, api_base, api_type, request_id, api_version, organization, **params)
#     127 @classmethod
#     128 def create(
#     129     cls,
#    (...)
#     136     **params,
#     137 ):
#     138     (
#     139         deployment_id,
#     140         engine,
#    (...)
#     150         api_key, api_base, api_type, api_version, organization, **params
#     151     )
# --> 153     response, _, api_key = requestor.request(
#     154         "post",
#     155         url,
#     156         params=params,
#     157         headers=headers,
#     158         stream=stream,
#     159         request_id=request_id,
#     160         request_timeout=request_timeout,
#     161     )
#     163     if stream:
#     164         # must be an iterator
#     165         assert not isinstance(response, OpenAIResponse)
#
# File ~/.local/lib/python3.8/site-packages/openai/api_requestor.py:230, in APIRequestor.request(self, method, url, params, headers, files, stream, request_id, request_timeout)
#     209 def request(
#     210     self,
#     211     method,
#    (...)
#     218     request_timeout: Optional[Union[float, Tuple[float, float]]] = None,
#     219 ) -> Tuple[Union[OpenAIResponse, Iterator[OpenAIResponse]], bool, str]:
#     220     result = self.request_raw(
#     221         method.lower(),
#     222         url,
#    (...)
#     228         request_timeout=request_timeout,
#     229     )
# --> 230     resp, got_stream = self._interpret_response(result, stream)
#     231     return resp, got_stream, self.api_key
#
# File ~/.local/lib/python3.8/site-packages/openai/api_requestor.py:624, in APIRequestor._interpret_response(self, result, stream)
#     616     return (
#     617         self._interpret_response_line(
#     618             line, result.status_code, result.headers, stream=True
#     619         )
#     620         for line in parse_stream(result.iter_lines())
#     621     ), True
#     622 else:
#     623     return (
# --> 624         self._interpret_response_line(
#     625             result.content.decode("utf-8"),
#     626             result.status_code,
#     627             result.headers,
#     628             stream=False,
#     629         ),
#     630         False,
#     631     )
#
# File ~/.local/lib/python3.8/site-packages/openai/api_requestor.py:687, in APIRequestor._interpret_response_line(self, rbody, rcode, rheaders, stream)
#     685 stream_error = stream and "error" in resp.data
#     686 if stream_error or not 200 <= rcode < 300:
# --> 687     raise self.handle_error_response(
#     688         rbody, rcode, resp.data, rheaders, stream_error=stream_error
#     689     )
#     690 return resp
#
# InvalidRequestError: Invalid URL (POST /v1/openai/deployments/gf-model-deploy-003/completions)

# %%
file_path='./test.json'
data = json.loads(Path(file_path).read_text())

pprint(data)
# Out:
# [{'comment': 'Annihilate the chinese government please. They are inbred '
#              "retards and shouldn't be able to call themselves, human fucking "
#              'pigs..',
#   'core_identity': ['origin'],
#   'sub_identity': ['specific country']},
#  {'comment': 'Fucking racist pigs.',
#   'core_identity': ['race'],
#   'sub_identity': ['other']},
#  {'comment': 'Man Chinese people are the worst',
#   'core_identity': ['race'],
#   'sub_identity': ['asian']},
#  {'comment': "I dislike most malays cause they're judgemental",
#   'core_identity': ['race', 'origin'],
#   'sub_identity': ['asian', 'specific country']},
#  {'comment': 'Fuck China. Bunch of hosers.',
#   'core_identity': ['origin'],
#   'sub_identity': ['specific country']},
#  {'comment': 'Good, fuck the Chinese',
#   'core_identity': ['origin'],
#   'sub_identity': ['specific country']},
#  {'comment': 'Fuck chinks',
#   'core_identity': ['race'],
#   'sub_identity': ['asian']},
#  {'comment': 'Screw the Chinese',
#   'core_identity': ['origin'],
#   'sub_identity': ['specific country']},
#  {'comment': 'Burn them I say That rattles the filthy Pakistani pigs',
#   'core_identity': ['race', 'religion', 'origin'],
#   'sub_identity': ['middle eastern', 'muslim', 'other', 'specific country']},
#  {'comment': 'Africans.... gross. I hope China wipes all of these nasty kni '
#              'ggers out.',
#   'core_identity': ['race', 'origin'],
#   'sub_identity': ['asian', 'black', 'specific country']}]

# %%
# Define the metadata extraction function.
def metadata_func(record: dict, metadata: dict) -> dict:

    metadata["core_identity"] = record.get("core_identity")
    metadata["sub_identity"] = record.get("sub_identity")
    metadata["source"] = None
    metadata["seq_num"] = None

    return metadata



loader = JSONLoader(
    file_path='./test.json',
    jq_schema='.[]',
    content_key="comment",
    metadata_func=metadata_func
)

data = loader.load()

pprint(data)
# Out:
# [Document(page_content="Annihilate the chinese government please. They are inbred retards and shouldn't be able to call themselves, human fucking pigs..", metadata={'source': None, 'seq_num': None, 'core_identity': ['origin'], 'sub_identity': ['specific country']}),
#  Document(page_content='Fucking racist pigs.', metadata={'source': None, 'seq_num': None, 'core_identity': ['race'], 'sub_identity': ['other']}),
#  Document(page_content='Man Chinese people are the worst', metadata={'source': None, 'seq_num': None, 'core_identity': ['race'], 'sub_identity': ['asian']}),
#  Document(page_content="I dislike most malays cause they're judgemental", metadata={'source': None, 'seq_num': None, 'core_identity': ['race', 'origin'], 'sub_identity': ['asian', 'specific country']}),
#  Document(page_content='Fuck China. Bunch of hosers.', metadata={'source': None, 'seq_num': None, 'core_identity': ['origin'], 'sub_identity': ['specific country']}),
#  Document(page_content='Good, fuck the Chinese', metadata={'source': None, 'seq_num': None, 'core_identity': ['origin'], 'sub_identity': ['specific country']}),
#  Document(page_content='Fuck chinks', metadata={'source': None, 'seq_num': None, 'core_identity': ['race'], 'sub_identity': ['asian']}),
#  Document(page_content='Screw the Chinese', metadata={'source': None, 'seq_num': None, 'core_identity': ['origin'], 'sub_identity': ['specific country']}),
#  Document(page_content='Burn them I say That rattles the filthy Pakistani pigs', metadata={'source': None, 'seq_num': None, 'core_identity': ['race', 'religion', 'origin'], 'sub_identity': ['middle eastern', 'muslim', 'other', 'specific country']}),
#  Document(page_content='Africans.... gross. I hope China wipes all of these nasty kni ggers out.', metadata={'source': None, 'seq_num': None, 'core_identity': ['race', 'origin'], 'sub_identity': ['asian', 'black', 'specific country']})]

# %%
from langchain.chains.question_answering import load_qa_chain
# instantiate QA chain
qa_chain = load_qa_chain(llm, chain_type="stuff", prompt=prompt_template)

# %%
pprint(prompt_template)
# Out:
# PromptTemplate(input_variables=['context', 'question'], output_parser=None, partial_variables={}, template="\nYou are a professional, specialised in reviewing abusive content which could violate sections 298 and 298A of Singapore's penal code.\nSection 298 of the Penal Code is a charge for uttering words, etc., with deliberate intent to wound the religious or racial feelings of any person.\nSection 298A of the Penal Code is a charge for promoting enmity between different groups on grounds of religion or race or doing acts prejudicial to maintenance of harmony.\nHate speech has been defined as all forms of expression which spread, incite, promote, or justify racial hatred, xenophobia, or other forms of hatred based on intolerance.\nYour instruction is to first evaluate if the comment at the end is considered a hate speech or not. Secondly, identify the possible core identity groups and the sub identity groups.\nUse only the context given below to carry out the task. If you don't know the answer, just say you don't know the answer.\n\nHere is the context:\n{context}\n\nHere is the comment:\n{question}\n", template_format='f-string', validate_template=True)

# %%
# ran with weaviate simiarlity + json as loader into langchain docs
output = qa_chain({"input_documents": data, "comment": "I hate chinese and malays they are pigs!"}, return_only_outputs=True)
print(output['output_text'])
# Out:
# Answer: Yes
# Core Identity Groups: Chinese, Malays
# Sub Identity Groups: None mentioned

# %%
# run using db without metadata
db = Weaviate(client=client, index_name="DataClass", text_key="comment")
retriever = db.as_retriever()
# pass example query to vector store and QA chain and print results
docs = db.similarity_search_by_text(query="I hate chinese and malays they are pigs!")
print(docs)
output = qa_chain({"input_documents": docs, "comment": "I hate chinese and malays they are pigs!"}, return_only_outputs=True)
print(output['output_text'])
# Out:
# [Document(page_content="Annihilate the chinese government please. They are inbred retards and shouldn't be able to call themselves, human fucking pigs..", metadata={}), Document(page_content='Fucking racist pigs.', metadata={}), Document(page_content='Man Chinese people are the worst', metadata={}), Document(page_content="I dislike most malays cause they're judgemental", metadata={})]
#
# Answer: Yes
# Core Identity Groups: Chinese, Malays
# Sub Identity Groups: None mentioned

# %%
# clean up methods to find context, need to be able to include the metadata

# %%
# put it inside app.py

# %%
# run restricted format in JSON

# %%
# run it in a langchain explaining the backend of it

# %%
# put embedding back into nomic
